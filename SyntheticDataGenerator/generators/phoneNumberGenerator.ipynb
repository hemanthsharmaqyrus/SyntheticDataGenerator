# %%
from faker import Faker
from collections import defaultdict
import random
from generatorUtils import LabelTransformations, DataTransformations

# %%
phone_number_labels = ['Phone', 'Phone Number', 'Mobile Number', 'Landline', 'Contact', 'Contact Number', 'Ph', 'Telephone']

# %%
class PhoneNumberGenerator:
    def __init__(self, num_of_samples):
        self.num_of_samples = num_of_samples
        self.labelTransformations = LabelTransformations()
        self.dataTransformations = DataTransformations()
        self.f = Faker()

    def country_code_transformations(self, country_code):
        return ['+' + country_code, '(' + country_code + ')']

    def generate_phone_numbers_with_country_codes(self, labels):
        labels = list(set(self.labelTransformations(labels)))

        phone_number_inputs = []
        phone_number_outputs = []

        for i in range(self.num_of_samples):
            '''generate country code and put it with + or in brackets'''
            

            '''randomly select label'''
            

            '''generate phone number of 5,6,7,8,9,10 length, with hyphen and with space'''
            #-----------------------------------------------------
            #For 5 digits
            #-----------------------------------------------------
            '''without space or hyphen'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)


            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=4)
            output_random_following_digits = self.generate_random_number(length=4)

            phone_number_inputs.append(label + ': ' + country_code + ' ' + start_number + input_random_following_digits)
            phone_number_outputs.append(country_code + ' ' + start_number + output_random_following_digits)

            '''with  hyphen'''
            
            if ' ' not in country_code:
                label = random.choice(labels)

                country_code = self.f.country_calling_code()
                country_code = country_code.split('+')[1]
                country_codes = self.country_code_transformations(country_code=country_code)
                country_code = random.choice(country_codes)

                start_number = str(random.randint(a=0, b=9))
                input_random_following_digits = self.generate_random_number(length=4)
                output_random_following_digits = self.generate_random_number(length=4)

                phone_number_inputs.append(label + ': ' + country_code + ' ' + self.dataTransformations.__seperate_using_hyphens__(start_number + input_random_following_digits, [3]))
                phone_number_outputs.append(country_code + ' ' +self.dataTransformations.__seperate_using_hyphens__(start_number + output_random_following_digits, [3]))


            '''with space'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)


            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=4)
            output_random_following_digits = self.generate_random_number(length=4)

            phone_number_inputs.append(label + ': ' + country_code + ' ' + self.dataTransformations.__seperate_using_spaces__(start_number + input_random_following_digits, [3]))
            phone_number_outputs.append(country_code + ' ' +self.dataTransformations.__seperate_using_spaces__(start_number + output_random_following_digits, [3]))

            #-----------------------------------------------------
            #For 6 digits
            #-----------------------------------------------------
            '''without space or hyphen'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)


            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=5)
            output_random_following_digits = self.generate_random_number(length=5)

            phone_number_inputs.append(label + ': ' + country_code + ' ' + start_number + input_random_following_digits)
            phone_number_outputs.append(country_code + ' ' +start_number + output_random_following_digits)

            '''with  hyphen'''
            if ' ' not in country_code:
                label = random.choice(labels)

                country_code = self.f.country_calling_code()
                country_code = country_code.split('+')[1]
                country_codes = self.country_code_transformations(country_code=country_code)
                country_code = random.choice(country_codes)


                start_number = str(random.randint(a=0, b=9))
                input_random_following_digits = self.generate_random_number(length=5)
                output_random_following_digits = self.generate_random_number(length=5)

                phone_number_inputs.append(label + ': ' + country_code + ' ' + self.dataTransformations.__seperate_using_hyphens__(start_number + input_random_following_digits, [3]))
                phone_number_outputs.append(country_code + ' ' + self.dataTransformations.__seperate_using_hyphens__(start_number + output_random_following_digits, [3]))


            '''with space'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)

            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=5)
            output_random_following_digits = self.generate_random_number(length=5)

            phone_number_inputs.append(label + ': ' + country_code + ' ' + self.dataTransformations.__seperate_using_spaces__(start_number + input_random_following_digits, [3]))
            phone_number_outputs.append(country_code + ' ' +self.dataTransformations.__seperate_using_spaces__(start_number + output_random_following_digits, [3]))
            

            #-----------------------------------------------------
            # For 7 digits
            #-----------------------------------------------------

            '''without space or hyphen'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)


            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=6)
            output_random_following_digits = self.generate_random_number(length=6)

            phone_number_inputs.append(label + ': ' + country_code + ' ' + start_number + input_random_following_digits)
            phone_number_outputs.append(country_code + ' ' +start_number + output_random_following_digits)

            '''with  hyphen'''
            if ' ' not in country_code:
                label = random.choice(labels)

                country_code = self.f.country_calling_code()
                country_code = country_code.split('+')[1]
                country_codes = self.country_code_transformations(country_code=country_code)
                country_code = random.choice(country_codes)


                start_number = str(random.randint(a=0, b=9))
                input_random_following_digits = self.generate_random_number(length=6)
                output_random_following_digits = self.generate_random_number(length=6)

                phone_number_inputs.append(label + ': ' + country_code + ' ' + self.dataTransformations.__seperate_using_hyphens__(start_number + input_random_following_digits, [4]))
                phone_number_outputs.append(country_code + ' ' +self.dataTransformations.__seperate_using_hyphens__(start_number + output_random_following_digits, [4]))


            '''with space'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)


            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=6)
            output_random_following_digits = self.generate_random_number(length=6)

            phone_number_inputs.append(label + ': ' + country_code + ' ' + self.dataTransformations.__seperate_using_spaces__(start_number + input_random_following_digits, [4]))
            phone_number_outputs.append(country_code + ' ' +self.dataTransformations.__seperate_using_spaces__(start_number + output_random_following_digits, [4]))

            #

            '''without space or hyphen'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)


            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=6)
            output_random_following_digits = self.generate_random_number(length=6)

            phone_number_inputs.append(label + ': ' + country_code + ' ' + start_number + input_random_following_digits)
            phone_number_outputs.append(country_code + ' ' +start_number + output_random_following_digits)

            '''with  hyphen'''
            if ' ' not in country_code:
                label = random.choice(labels)

                country_code = self.f.country_calling_code()
                country_code = country_code.split('+')[1]
                country_codes = self.country_code_transformations(country_code=country_code)
                country_code = random.choice(country_codes)

                start_number = str(random.randint(a=0, b=9))
                input_random_following_digits = self.generate_random_number(length=6)
                output_random_following_digits = self.generate_random_number(length=6)

                phone_number_inputs.append(label + ': ' + country_code + ' ' + self.dataTransformations.__seperate_using_hyphens__(start_number + input_random_following_digits, [4]))
                phone_number_outputs.append(country_code + ' ' +self.dataTransformations.__seperate_using_hyphens__(start_number + output_random_following_digits, [4]))


            '''with space'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)


            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=6)
            output_random_following_digits = self.generate_random_number(length=6)

            phone_number_inputs.append(label + ': ' + country_code + ' ' + self.dataTransformations.__seperate_using_spaces__(start_number + input_random_following_digits, [4]))
            phone_number_outputs.append(country_code + ' ' +self.dataTransformations.__seperate_using_spaces__(start_number + output_random_following_digits, [4]))


            # For 8 digits

            '''without space or hyphen'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)

            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=7)
            output_random_following_digits = self.generate_random_number(length=7)

            phone_number_inputs.append(label + ': ' + country_code + ' ' + start_number + input_random_following_digits)
            phone_number_outputs.append(country_code + ' ' +start_number + output_random_following_digits)

            '''with  hyphen'''
            if ' ' not in country_code:
                label = random.choice(labels)

                country_code = self.f.country_calling_code()
                country_code = country_code.split('+')[1]
                country_codes = self.country_code_transformations(country_code=country_code)
                country_code = random.choice(country_codes)


                start_number = str(random.randint(a=0, b=9))
                input_random_following_digits = self.generate_random_number(length=7)
                output_random_following_digits = self.generate_random_number(length=7)

                phone_number_inputs.append(label + ': ' + country_code + ' ' + self.dataTransformations.__seperate_using_hyphens__(start_number + input_random_following_digits, [4]))
                phone_number_outputs.append(country_code + ' ' +self.dataTransformations.__seperate_using_hyphens__(start_number + output_random_following_digits, [4]))


            '''with space'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)

            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=7)
            output_random_following_digits = self.generate_random_number(length=7)

            phone_number_inputs.append(label + ': ' + country_code + ' ' + self.dataTransformations.__seperate_using_spaces__(start_number + input_random_following_digits, [4]))
            phone_number_outputs.append(country_code + ' ' +self.dataTransformations.__seperate_using_spaces__(start_number + output_random_following_digits, [4]))

            # For 9 digits

            '''without space or hyphen'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)


            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=8)
            output_random_following_digits = self.generate_random_number(length=8)

            phone_number_inputs.append(label + ': ' + country_code + ' ' + start_number + input_random_following_digits)
            phone_number_outputs.append(country_code + ' ' +start_number + output_random_following_digits)

            '''with  hyphen'''
            if ' ' not in country_code:
                label = random.choice(labels)

                country_code = self.f.country_calling_code()
                country_code = country_code.split('+')[1]
                country_codes = self.country_code_transformations(country_code=country_code)
                country_code = random.choice(country_codes)

                start_number = str(random.randint(a=0, b=9))
                input_random_following_digits = self.generate_random_number(length=8)
                output_random_following_digits = self.generate_random_number(length=8)

                phone_number_inputs.append(label + ': ' + country_code + ' ' + self.dataTransformations.__seperate_using_hyphens__(start_number + input_random_following_digits, [3,6]))
                phone_number_outputs.append(country_code + ' ' +self.dataTransformations.__seperate_using_hyphens__(start_number + output_random_following_digits, [3,6]))


            '''with space'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)

            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=8)
            output_random_following_digits = self.generate_random_number(length=8)

            phone_number_inputs.append(label + ': ' + country_code + ' ' + self.dataTransformations.__seperate_using_spaces__(start_number + input_random_following_digits, [3,6]))
            phone_number_outputs.append(country_code + ' ' +self.dataTransformations.__seperate_using_spaces__(start_number + output_random_following_digits, [3,6]))


            # For 10 digits

            '''without space or hyphen'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)

            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=9)
            output_random_following_digits = self.generate_random_number(length=9)

            phone_number_inputs.append(label + ': ' + country_code + ' ' + start_number + input_random_following_digits)
            phone_number_outputs.append(country_code + ' ' +start_number + output_random_following_digits)

            '''with  hyphen at 5'''
            if ' ' not in country_code:
                label = random.choice(labels)

                country_code = self.f.country_calling_code()
                country_code = country_code.split('+')[1]
                country_codes = self.country_code_transformations(country_code=country_code)
                country_code = random.choice(country_codes)

                start_number = str(random.randint(a=0, b=9))
                input_random_following_digits = self.generate_random_number(length=9)
                output_random_following_digits = self.generate_random_number(length=9)

                phone_number_inputs.append(label + ': ' + country_code + ' ' + self.dataTransformations.__seperate_using_hyphens__(start_number + input_random_following_digits, [5]))
                phone_number_outputs.append(country_code + ' ' +self.dataTransformations.__seperate_using_hyphens__(start_number + output_random_following_digits, [5]))


            '''with space at 5'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)

            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=9)
            output_random_following_digits = self.generate_random_number(length=9)

            phone_number_inputs.append(label + ': ' + country_code + ' ' + self.dataTransformations.__seperate_using_spaces__(start_number + input_random_following_digits, [5]))
            phone_number_outputs.append(country_code + ' ' +self.dataTransformations.__seperate_using_spaces__(start_number + output_random_following_digits, [5]))

            '''with  hyphen at 4,7'''
            if ' ' not in country_code:
                label = random.choice(labels)

                country_code = self.f.country_calling_code()
                country_code = country_code.split('+')[1]
                country_codes = self.country_code_transformations(country_code=country_code)
                country_code = random.choice(country_codes)

                start_number = str(random.randint(a=0, b=9))
                input_random_following_digits = self.generate_random_number(length=9)
                output_random_following_digits = self.generate_random_number(length=9)

                phone_number_inputs.append(label + ': ' + country_code + ' ' + self.dataTransformations.__seperate_using_hyphens__(start_number + input_random_following_digits, [4,7]))
                phone_number_outputs.append(country_code + ' ' +self.dataTransformations.__seperate_using_hyphens__(start_number + output_random_following_digits, [4,7]))


            '''with space at 4,7'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)

            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=9)
            output_random_following_digits = self.generate_random_number(length=9)

            phone_number_inputs.append(label + ': ' + country_code + ' ' + self.dataTransformations.__seperate_using_spaces__(start_number + input_random_following_digits, [4,7]))
            phone_number_outputs.append(country_code + ' ' +self.dataTransformations.__seperate_using_spaces__(start_number + output_random_following_digits, [4,7]))

            edited_phone_number_inputs = []
            edited_phone_number_outputs = []
            for input, output in zip(phone_number_inputs, phone_number_outputs):
                delete_choice = random.choice([0,1])
                # print('input is', input)
                # print('output is', output)
                
                if ') ' in input and delete_choice == 1:
                    input = input.replace(') ', ')')
                    output = output.replace(') ', ')')
                    edited_phone_number_inputs.append(input)
                    edited_phone_number_outputs.append(output)
                else:
                    edited_phone_number_inputs.append(input)
                    edited_phone_number_outputs.append(output)
                

        return edited_phone_number_inputs, edited_phone_number_outputs

    def generate_phone_numbers_without_country_codes(self, labels):
        labels = list(set(self.labelTransformations(labels)))

        phone_number_inputs = []
        phone_number_outputs = []

        for i in range(self.num_of_samples):
            '''generate country code and put it with + or in brackets'''
            

            '''randomly select label'''
            

            '''generate phone number of 5,6,7,8,9,10 length, with hyphen and with space'''
            #-----------------------------------------------------
            #For 5 digits
            #-----------------------------------------------------
            '''without space or hyphen'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)


            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=4)
            output_random_following_digits = self.generate_random_number(length=4)

            phone_number_inputs.append(label + ': ' +  start_number + input_random_following_digits)
            phone_number_outputs.append(start_number + output_random_following_digits)

            '''with  hyphen'''
            
            if ' ' not in country_code:
                label = random.choice(labels)

                country_code = self.f.country_calling_code()
                country_code = country_code.split('+')[1]
                country_codes = self.country_code_transformations(country_code=country_code)
                country_code = random.choice(country_codes)

                start_number = str(random.randint(a=0, b=9))
                input_random_following_digits = self.generate_random_number(length=4)
                output_random_following_digits = self.generate_random_number(length=4)

                phone_number_inputs.append(label + ': ' +  self.dataTransformations.__seperate_using_hyphens__(start_number + input_random_following_digits, [3]))
                phone_number_outputs.append(self.dataTransformations.__seperate_using_hyphens__(start_number + output_random_following_digits, [3]))


            '''with space'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)


            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=4)
            output_random_following_digits = self.generate_random_number(length=4)

            phone_number_inputs.append(label + ': ' +  self.dataTransformations.__seperate_using_spaces__(start_number + input_random_following_digits, [3]))
            phone_number_outputs.append(self.dataTransformations.__seperate_using_spaces__(start_number + output_random_following_digits, [3]))

            #-----------------------------------------------------
            #For 6 digits
            #-----------------------------------------------------
            '''without space or hyphen'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)


            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=5)
            output_random_following_digits = self.generate_random_number(length=5)

            phone_number_inputs.append(label + ': ' +  start_number + input_random_following_digits)
            phone_number_outputs.append(start_number + output_random_following_digits)

            '''with  hyphen'''
            if ' ' not in country_code:
                label = random.choice(labels)

                country_code = self.f.country_calling_code()
                country_code = country_code.split('+')[1]
                country_codes = self.country_code_transformations(country_code=country_code)
                country_code = random.choice(country_codes)


                start_number = str(random.randint(a=0, b=9))
                input_random_following_digits = self.generate_random_number(length=5)
                output_random_following_digits = self.generate_random_number(length=5)

                phone_number_inputs.append(label + ': ' +  self.dataTransformations.__seperate_using_hyphens__(start_number + input_random_following_digits, [3]))
                phone_number_outputs.append(self.dataTransformations.__seperate_using_hyphens__(start_number + output_random_following_digits, [3]))


            '''with space'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)

            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=5)
            output_random_following_digits = self.generate_random_number(length=5)

            phone_number_inputs.append(label + ': ' +  self.dataTransformations.__seperate_using_spaces__(start_number + input_random_following_digits, [3]))
            phone_number_outputs.append(self.dataTransformations.__seperate_using_spaces__(start_number + output_random_following_digits, [3]))
            

            #-----------------------------------------------------
            # For 7 digits
            #-----------------------------------------------------

            '''without space or hyphen'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)


            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=6)
            output_random_following_digits = self.generate_random_number(length=6)

            phone_number_inputs.append(label + ': ' +  start_number + input_random_following_digits)
            phone_number_outputs.append(start_number + output_random_following_digits)

            '''with  hyphen'''
            if ' ' not in country_code:
                label = random.choice(labels)

                country_code = self.f.country_calling_code()
                country_code = country_code.split('+')[1]
                country_codes = self.country_code_transformations(country_code=country_code)
                country_code = random.choice(country_codes)


                start_number = str(random.randint(a=0, b=9))
                input_random_following_digits = self.generate_random_number(length=6)
                output_random_following_digits = self.generate_random_number(length=6)

                phone_number_inputs.append(label + ': ' +  self.dataTransformations.__seperate_using_hyphens__(start_number + input_random_following_digits, [4]))
                phone_number_outputs.append(self.dataTransformations.__seperate_using_hyphens__(start_number + output_random_following_digits, [4]))


            '''with space'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)


            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=6)
            output_random_following_digits = self.generate_random_number(length=6)

            phone_number_inputs.append(label + ': ' +  self.dataTransformations.__seperate_using_spaces__(start_number + input_random_following_digits, [4]))
            phone_number_outputs.append(self.dataTransformations.__seperate_using_spaces__(start_number + output_random_following_digits, [4]))

            #

            '''without space or hyphen'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)


            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=6)
            output_random_following_digits = self.generate_random_number(length=6)

            phone_number_inputs.append(label + ': ' +  start_number + input_random_following_digits)
            phone_number_outputs.append(start_number + output_random_following_digits)

            '''with  hyphen'''
            if ' ' not in country_code:
                label = random.choice(labels)

                country_code = self.f.country_calling_code()
                country_code = country_code.split('+')[1]
                country_codes = self.country_code_transformations(country_code=country_code)
                country_code = random.choice(country_codes)

                start_number = str(random.randint(a=0, b=9))
                input_random_following_digits = self.generate_random_number(length=6)
                output_random_following_digits = self.generate_random_number(length=6)

                phone_number_inputs.append(label + ': ' +  self.dataTransformations.__seperate_using_hyphens__(start_number + input_random_following_digits, [4]))
                phone_number_outputs.append(self.dataTransformations.__seperate_using_hyphens__(start_number + output_random_following_digits, [4]))


            '''with space'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)


            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=6)
            output_random_following_digits = self.generate_random_number(length=6)

            phone_number_inputs.append(label + ': ' +  self.dataTransformations.__seperate_using_spaces__(start_number + input_random_following_digits, [4]))
            phone_number_outputs.append(self.dataTransformations.__seperate_using_spaces__(start_number + output_random_following_digits, [4]))


            # For 8 digits

            '''without space or hyphen'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)

            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=7)
            output_random_following_digits = self.generate_random_number(length=7)

            phone_number_inputs.append(label + ': ' +  start_number + input_random_following_digits)
            phone_number_outputs.append(start_number + output_random_following_digits)

            '''with  hyphen'''
            if ' ' not in country_code:
                label = random.choice(labels)

                country_code = self.f.country_calling_code()
                country_code = country_code.split('+')[1]
                country_codes = self.country_code_transformations(country_code=country_code)
                country_code = random.choice(country_codes)


                start_number = str(random.randint(a=0, b=9))
                input_random_following_digits = self.generate_random_number(length=7)
                output_random_following_digits = self.generate_random_number(length=7)

                phone_number_inputs.append(label + ': ' +  self.dataTransformations.__seperate_using_hyphens__(start_number + input_random_following_digits, [4]))
                phone_number_outputs.append(self.dataTransformations.__seperate_using_hyphens__(start_number + output_random_following_digits, [4]))


            '''with space'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)

            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=7)
            output_random_following_digits = self.generate_random_number(length=7)

            phone_number_inputs.append(label + ': ' +  self.dataTransformations.__seperate_using_spaces__(start_number + input_random_following_digits, [4]))
            phone_number_outputs.append(self.dataTransformations.__seperate_using_spaces__(start_number + output_random_following_digits, [4]))

            # For 9 digits

            '''without space or hyphen'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)


            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=8)
            output_random_following_digits = self.generate_random_number(length=8)

            phone_number_inputs.append(label + ': ' +  start_number + input_random_following_digits)
            phone_number_outputs.append(start_number + output_random_following_digits)

            '''with  hyphen'''
            if ' ' not in country_code:
                label = random.choice(labels)

                country_code = self.f.country_calling_code()
                country_code = country_code.split('+')[1]
                country_codes = self.country_code_transformations(country_code=country_code)
                country_code = random.choice(country_codes)

                start_number = str(random.randint(a=0, b=9))
                input_random_following_digits = self.generate_random_number(length=8)
                output_random_following_digits = self.generate_random_number(length=8)

                phone_number_inputs.append(label + ': ' +  self.dataTransformations.__seperate_using_hyphens__(start_number + input_random_following_digits, [3,6]))
                phone_number_outputs.append(self.dataTransformations.__seperate_using_hyphens__(start_number + output_random_following_digits, [3,6]))


            '''with space'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)

            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=8)
            output_random_following_digits = self.generate_random_number(length=8)

            phone_number_inputs.append(label + ': ' +  self.dataTransformations.__seperate_using_spaces__(start_number + input_random_following_digits, [3,6]))
            phone_number_outputs.append(self.dataTransformations.__seperate_using_spaces__(start_number + output_random_following_digits, [3,6]))


            # For 10 digits

            '''without space or hyphen'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)

            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=9)
            output_random_following_digits = self.generate_random_number(length=9)

            phone_number_inputs.append(label + ': ' +  start_number + input_random_following_digits)
            phone_number_outputs.append(start_number + output_random_following_digits)

            '''with  hyphen at 5'''
            if ' ' not in country_code:
                label = random.choice(labels)

                country_code = self.f.country_calling_code()
                country_code = country_code.split('+')[1]
                country_codes = self.country_code_transformations(country_code=country_code)
                country_code = random.choice(country_codes)

                start_number = str(random.randint(a=0, b=9))
                input_random_following_digits = self.generate_random_number(length=9)
                output_random_following_digits = self.generate_random_number(length=9)

                phone_number_inputs.append(label + ': ' +  self.dataTransformations.__seperate_using_hyphens__(start_number + input_random_following_digits, [5]))
                phone_number_outputs.append(self.dataTransformations.__seperate_using_hyphens__(start_number + output_random_following_digits, [5]))


            '''with space at 5'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)

            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=9)
            output_random_following_digits = self.generate_random_number(length=9)

            phone_number_inputs.append(label + ': ' +  self.dataTransformations.__seperate_using_spaces__(start_number + input_random_following_digits, [5]))
            phone_number_outputs.append(self.dataTransformations.__seperate_using_spaces__(start_number + output_random_following_digits, [5]))

            '''with  hyphen at 4,7'''
            if ' ' not in country_code:
                label = random.choice(labels)

                country_code = self.f.country_calling_code()
                country_code = country_code.split('+')[1]
                country_codes = self.country_code_transformations(country_code=country_code)
                country_code = random.choice(country_codes)

                start_number = str(random.randint(a=0, b=9))
                input_random_following_digits = self.generate_random_number(length=9)
                output_random_following_digits = self.generate_random_number(length=9)

                phone_number_inputs.append(label + ': ' +  self.dataTransformations.__seperate_using_hyphens__(start_number + input_random_following_digits, [4,7]))
                phone_number_outputs.append(self.dataTransformations.__seperate_using_hyphens__(start_number + output_random_following_digits, [4,7]))


            '''with space at 4,7'''
            label = random.choice(labels)

            country_code = self.f.country_calling_code()
            country_code = country_code.split('+')[1]
            country_codes = self.country_code_transformations(country_code=country_code)
            country_code = random.choice(country_codes)

            start_number = str(random.randint(a=0, b=9))
            input_random_following_digits = self.generate_random_number(length=9)
            output_random_following_digits = self.generate_random_number(length=9)

            phone_number_inputs.append(label + ': ' +  self.dataTransformations.__seperate_using_spaces__(start_number + input_random_following_digits, [4,7]))
            phone_number_outputs.append(self.dataTransformations.__seperate_using_spaces__(start_number + output_random_following_digits, [4,7]))

        return phone_number_inputs, phone_number_outputs

    
    def generate_random_number(self, length):
        start = eval(''.join(['1'] + ['0' for i in range(1, length-1)]))
        end = eval(''.join(['9' for i in range(1, length)]))

        start = int(eval('1' + str(start)))
        end = int(eval('9' + str(end)))


        random_number = str(random.randint(a=start, b=end))
        return random_number

# %%
phoneNumberGenerator = PhoneNumberGenerator(num_of_samples=300)

# %%
input_with_country_code, output_with_country_code = phoneNumberGenerator.generate_phone_numbers_with_country_codes(phone_number_labels)

# %%
input_without_country_code, output_without_country_code = phoneNumberGenerator.generate_phone_numbers_without_country_codes(phone_number_labels)

# %%
input = input_with_country_code + input_without_country_code
output = output_with_country_code + output_without_country_code

# %%
import pandas as pd
res = pd.DataFrame(columns=['input_entity', 'output_entity'])

# %%
res['input_entity'] = input
res['output_entity'] = output

# %%
len(res)
# Out:
# 12588

# %%
res.to_csv('phone_number_data.csv', index=False)
