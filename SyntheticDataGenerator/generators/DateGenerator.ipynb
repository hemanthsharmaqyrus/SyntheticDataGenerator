# %%
import random
from faker import Faker
from generatorUtils import LabelTransformations

from datetime import date, datetime as dt

# %%
labels = ['date', 'published date', 'transaction date', 
'date of birth', 'date of commencement', 'date of joining',
'end date', 'date of transaction', 'date of purchase', 'last authentication date', 
'role created date', 'creation date', 'modified date', 'last modified date', 'login created date']

# %%
class DateGenerator:
    def __init__(self, num_of_samples):
        self.num_of_samples = num_of_samples
        self.labelTransformations = LabelTransformations()

    def suffix(self, d):
        return 'th' if 11<=d<=13 else {1:'st',2:'nd',3:'rd'}.get(d%10, 'th')

    def custom_strftime(self, format, t):
        return t.strftime(format).replace('{S}', str(t.day) + self.suffix(t.day))

    def get_random_date(self,):
        start_dt = date.today().replace(day=1, month=1).toordinal()
        end_dt = date.today().toordinal()
        random_day = dt.fromordinal(random.randint(start_dt, end_dt))
        return random_day

    def generateDates(self, labels):
        f = Faker()
        labels = list(set(self.labelTransformations(labels)))
        date_input_strings = []
        date_output_strings = []
        
        for i in range(self.num_of_samples):
            # January 1, 1996
            label = random.choice(labels)
            year = f.year()
            date_input_strings.append(f'{label}: ' + f.month_name() + ' ' + f.day_of_month() + ', ' + year)
            date_output_strings.append(f.month_name() + ' ' + f.day_of_month() + ', ' + year)

            # 1 January 2001
            label = random.choice(labels)
            year = f.year()
            date_input_strings.append(f'{label}: ' + f.day_of_month() + ' ' + f.month_name() + ' ' + year)
            date_output_strings.append(f.day_of_month() + ' ' + f.month_name() + ' ' + year)

            # Jan 1, 1996
            label = random.choice(labels)
            year = f.year()
            date_input_strings.append(f'{label}: ' + f.month_name()[:3] + ' ' + f.day_of_month() + ', ' + year)
            date_output_strings.append(f.month_name() + ' ' + f.day_of_month()[:3] + ', ' + year)

            # 1 Jan 2001
            label = random.choice(labels)
            year = f.year()
            date_input_strings.append(f'{label}: ' + f.day_of_month()[:3] + ' ' + f.month_name() + ' ' + year)
            date_output_strings.append(f.day_of_month() + ' ' + f.month_name()[:3] + ' ' + year)

            # 2001-01-12
            label = random.choice(labels)
            
            date_input_strings.append(f'{label}: ' + f.date())
            date_output_strings.append(f.date())

            # 12-01-1994
            label = random.choice(labels)
            
            date_input_strings.append(f'{label}: ' + f.date(pattern='%d-%m-%Y'))
            date_output_strings.append(f.date(pattern='%d-%m-%Y'))

            # 2003/01/21
            label = random.choice(labels)
            
            date_input_strings.append(f'{label}: ' + f.date(pattern='%Y/%m/%d'))
            date_output_strings.append(f.date(pattern='%Y/%m/%d'))

            # 01/01/1993
            label = random.choice(labels)
            
            date_input_strings.append(f'{label}: ' + f.date(pattern='%d/%m/%Y'))
            date_output_strings.append(f.date(pattern='%d/%m/%Y'))

            # March 2nd, 2021
            label = random.choice(labels)
            date_input_strings.append(f'{label}: ' + self.custom_strftime('%B {S}, %Y', self.get_random_date()))
            date_output_strings.append(self.custom_strftime('%B {S}, %Y', self.get_random_date()))

            #March 6th
            label = random.choice(labels)
            date_input_strings.append(f'{label}: ' + self.custom_strftime('%B {S}', self.get_random_date()))
            date_output_strings.append(self.custom_strftime('%B {S}', self.get_random_date()))

            #30th March
            label = random.choice(labels)
            date_input_strings.append(f'{label}: ' + self.custom_strftime('{S} %B', self.get_random_date()))
            date_output_strings.append(self.custom_strftime('{S} %B', self.get_random_date()))

            #Mar 6th
            d = self.custom_strftime('{S} %B', self.get_random_date())
            d = d.split(' ')[1][:3] + ' ' + d.split(' ')[0]
            date_input_strings.append(f'{label}: ' + d)

            d = self.custom_strftime('{S} %B', self.get_random_date())
            d = d.split(' ')[1][:3] + ' ' + d.split(' ')[0]
            date_output_strings.append(d)

            #6th Mar
            d = self.custom_strftime('{S} %B', self.get_random_date())
            d = d.split(' ')[0] + ' ' + d.split(' ')[1][:3]
            date_input_strings.append(f'{label}: ' + d)
            
            d = self.custom_strftime('{S} %B', self.get_random_date())
            d = d.split(' ')[0] + ' ' + d.split(' ')[1][:3]
            date_output_strings.append(d)

        return date_input_strings, date_output_strings

# %%
dateGenerator = DateGenerator(num_of_samples=300)

# %%
input, output = dateGenerator.generateDates(labels)

# %%
list(zip(input, output))
# Out:
# [('roleCreatedDate: December 19, 2009', 'June 01, 2009'),
#  ('creation-date: 13 January 1998', '17 September 1998'),
#  ('transactiondate: Oct 07, 2000', 'February 15, 2000'),
#  ('Date Of Purchase: 23 February 2018', '07 Sep 2018'),
#  ('Last-Authentication-Date: 2013-12-06', '1993-08-10'),
#  ('DateOfCommencement: 27-05-1974', '05-03-1970'),
#  ('LOGIN_CREATED_DATE: 2009/10/17', '1982/03/14'),
#  ('dateofjoining: 27/03/1987', '14/05/1981'),
#  ('modified_date: February 13th, 2022', 'March 10th, 2022'),
#  ('ROLE_CREATED_DATE: January 26th', 'January 7th'),
#  ('last_authentication_date: 16th April', '28th January'),
#  ('last_authentication_date: May 3rd', 'Apr 19th'),
#  ('last_authentication_date: 4th Feb', '12th Jan'),
#  ('roleCreatedDate: August 09, 1976', 'June 26, 1976'),
#  ('modified-date: 17 August 1997', '17 August 1997'),
#  ('date-of-transaction: Feb 06, 1998', 'March 20, 1998'),
#  ('MODIFIED-DATE: 26 April 2011', '30 May 2011'),
#  ('role-created-date: 1990-08-03', '1990-02-23'),
#  ('Login_Created_Date: 29-05-2007', '07-01-1998'),
#  ('last modified date: 1972/06/22', '1985/06/23'),
#  ('last_authentication_date: 16/10/1971', '20/07/1980'),
#  ('TRANSACTION-DATE: March 23rd, 2022', 'March 24th, 2022'),
#  ('role_created_date: January 6th', 'January 4th'),
#  ('login_created_date: 17th March', '21st April'),
#  ('login_created_date: May 2nd', 'May 18th'),
#  ('login_created_date: 8th Mar', '9th Mar'),
#  ('dateofbirth: October 05, 1986', 'February 24, 1986'),
#  ('TransactionDate: 04 February 1994', '23 June 1994'),
#  ('DATEOFPURCHASE: Oct 12, 1991', 'June 30, 1991'),
#  ('Last_Modified_Date: 07 October 1988', '05 Nov 1988'),
#  ('Published Date: 1982-01-04', '1980-07-16'),
#  ('modified-date: 30-01-1993', '25-11-2017'),
#  ('loginCreatedDate: 1973/06/12', '1993/10/24'),
#  ('Date: 04/04/2007', '30/07/2020'),
#  ('DATE-OF-JOINING: June 16th, 2022', 'February 28th, 2022'),
#  ('DATE OF TRANSACTION: March 17th', 'April 27th'),
#  ('PUBLISHEDDATE: 1st March', '4th May'),
#  ('PUBLISHEDDATE: Feb 24th', 'Feb 11th'),
#  ('PUBLISHEDDATE: 2nd Mar', '7th Feb'),
#  ('LOGIN CREATED DATE: February 18, 1999', 'April 15, 1999'),
#  ('LAST MODIFIED DATE: 16 July 1978', '01 July 1978'),
#  ('DATE OF PURCHASE: Dec 21, 2003', 'January 17, 2003'),
#  ('LOGIN-CREATED-DATE: 24 October 1989', '25 Sep 1989'),
#  ('Creation Date: 1984-10-04', '1972-11-17'),
#  ('LASTMODIFIEDDATE: 28-04-1982', '27-10-1970'),
#  ('DateOfBirth: 1979/11/17', '1991/03/24'),
#  ('last modified date: 24/12/1980', '08/05/2012'),
#  ('LAST_MODIFIED_DATE: January 15th, 2022', 'January 20th, 2022'),
#  ('Date-Of-Joining: April 23rd', 'June 9th'),
#  ('published_date: 4th January', '15th February'),
#  ('published_date: Apr 25th', 'Mar 26th'),
#  ('published_date: 25th Apr', '3rd Mar'),
#  ('last-authentication-date: January 24, 1978', 'November 21, 1978'),
#  ('creation date: 10 October 1986', '06 January 1986'),
#  ('ROLE-CREATED-DATE: Jan 30, 1999', 'March 12, 1999'),
#  ('end-date: 18 May 2004', '20 Sep 2004'),
#  ('role created date: 1980-10-20', '1995-02-08'),
#  ('DATE: 22-10-1985', '09-04-1987'),
#  ('Date_Of_Purchase: 1987/02/12', '2020/08/17'),
#  ('login-created-date: 21/06/2020', '24/08/1980'),
#  ('creationdate: April 16th, 2022', 'April 1st, 2022'),
#  ('Date: April 12th', 'April 13th'),
#  ('DATEOFJOINING: 13th March', '11th January'),
#  ('DATEOFJOINING: Mar 7th', 'Feb 12th'),
#  ('DATEOFJOINING: 5th Jan', '19th Jun'),
#  ('Date Of Joining: January 07, 1973', 'July 08, 1973'),
#  ('Login Created Date: 09 December 2006', '29 May 2006'),
#  ('DATE_OF_PURCHASE: Oct 14, 1977', 'July 04, 1977'),
#  ('LastModifiedDate: 12 September 1993', '04 Jun 1993'),
#  ('DATE OF BIRTH: 2020-02-07', '1983-12-01'),
#  ('LOGIN-CREATED-DATE: 27-05-1975', '03-01-1976'),
#  ('DateOfTransaction: 1972/10/31', '2004/08/15'),
#  ('Modified-Date: 04/02/1984', '03/04/2013'),
#  ('DATEOFCOMMENCEMENT: April 13th, 2022', 'June 8th, 2022'),
#  ('Date_Of_Transaction: February 8th', 'April 7th'),
#  ('last_authentication_date: 29th January', '17th March'),
#  ('last_authentication_date: Feb 7th', 'Feb 14th'),
#  ('last_authentication_date: 11th Jan', '4th Feb'),
#  ('MODIFIED_DATE: May 17, 1973', 'May 28, 1973'),
#  ('END_DATE: 06 April 2021', '17 August 2021'),
#  ('enddate: Apr 18, 1988', 'November 27, 1988'),
#  ('creation-date: 24 November 2006', '16 May 2006'),
#  ('DateOfTransaction: 1991-10-14', '1982-04-06'),
#  ('date_of_birth: 17-03-2005', '13-04-1977'),
#  ('CREATIONDATE: 2000/09/02', '1970/05/14'),
#  ('date of birth: 24/10/1970', '19/03/1979'),
#  ('DATE_OF_BIRTH: February 14th, 2022', 'February 21st, 2022'),
#  ('LastModifiedDate: February 14th', 'April 6th'),
#  ('Date Of Purchase: 24th April', '12th February'),
#  ('Date Of Purchase: May 20th', 'Jan 1st'),
#  ('Date Of Purchase: 18th Jan', '19th Apr'),
#  ('Date Of Purchase: July 17, 1970', 'April 28, 1970'),
#  ('end date: 12 April 1997', '11 June 1997'),
#  ('login-created-date: Mar 22, 1970', 'January 30, 1970'),
#  ('DATE OF BIRTH: 28 September 2021', '25 Aug 2021'),
#  ('Modified-Date: 2001-10-20', '2001-09-12'),
#  ('modifiedDate: 28-09-2016', '07-03-2009'),
#  ('CREATIONDATE: 1999/04/08', '1997/01/18'),
#  ('transaction-date: 14/11/2008', '23/05/1998'),
#  ('Date_Of_Birth: May 10th, 2022', 'April 8th, 2022'),
#  ('PUBLISHED DATE: June 16th', 'February 23rd'),
#  ('LastAuthenticationDate: 8th February', '10th March'),
#  ('LastAuthenticationDate: Feb 23rd', 'Jun 3rd'),
#  ('LastAuthenticationDate: 16th Jun', '1st Jun'),
#  ('Creation_Date: June 11, 1971', 'January 29, 1971'),
#  ('PUBLISHEDDATE: 03 December 1993', '13 February 1993'),
#  ('Last Authentication Date: May 18, 2021', 'May 29, 2021'),
#  ('date_of_birth: 23 June 2007', '29 Feb 2007'),
#  ('creationDate: 2009-09-17', '2006-11-23'),
#  ('Date Of Commencement: 23-02-1998', '06-08-2012'),
#  ('Date-Of-Purchase: 2016/08/15', '1971/04/29'),
#  ('date_of_joining: 01/07/1986', '06/06/2019'),
#  ('dateoftransaction: March 8th, 2022', 'April 28th, 2022'),
#  ('CREATION-DATE: May 25th', 'April 25th'),
#  ('CREATIONDATE: 30th January', '24th May'),
#  ('CREATIONDATE: Mar 15th', 'Apr 22nd'),
#  ('CREATIONDATE: 7th Apr', '13th Jun'),
#  ('Modified-Date: May 12, 1984', 'February 08, 1984'),
#  ('DATE_OF_TRANSACTION: 10 November 1986', '18 October 1986'),
#  ('transaction date: Jun 18, 1987', 'April 31, 1987'),
#  ('LAST_MODIFIED_DATE: 06 March 2013', '16 Apr 2013'),
#  ('End Date: 1995-04-28', '1976-02-11'),
#  ('TRANSACTION_DATE: 16-02-2004', '11-08-1985'),
#  ('date of purchase: 1996/06/17', '1980/06/15'),
#  ('ROLECREATEDDATE: 14/05/1997', '27/03/2010'),
#  ('date of birth: February 25th, 2022', 'January 30th, 2022'),
#  ('Last Modified Date: January 13th', 'June 8th'),
#  ('published_date: 1st April', '18th February'),
#  ('published_date: Apr 27th', 'Mar 3rd'),
#  ('published_date: 14th Apr', '20th Apr'),
#  ('DateOfPurchase: May 30, 1971', 'November 18, 1971'),
#  ('published date: 12 June 2002', '18 November 2002'),
#  ('Date_Of_Joining: Nov 12, 1992', 'September 07, 1992'),
#  ('DATE: 14 April 2017', '20 Mar 2017'),
#  ('modified_date: 1993-01-12', '1997-11-25'),
#  ('date of joining: 06-09-1993', '25-06-1990'),
#  ('creationDate: 1994/12/07', '1993/05/10'),
#  ('creationDate: 15/11/1985', '21/12/1992'),
#  ('DATE OF COMMENCEMENT: January 19th, 2022', 'April 26th, 2022'),
#  ('DATEOFTRANSACTION: January 19th', 'May 8th'),
#  ('DATEOFPURCHASE: 31st January', '12th March'),
#  ('DATEOFPURCHASE: Feb 9th', 'Feb 8th'),
#  ('DATEOFPURCHASE: 13th Jun', '4th May'),
#  ('LastModifiedDate: August 07, 2011', 'July 09, 2011'),
#  ('dateofbirth: 02 January 2002', '05 October 2002'),
#  ('last_authentication_date: Nov 15, 1994', 'June 08, 1994'),
#  ('Date Of Joining: 01 September 2008', '28 Dec 2008'),
#  ('loginCreatedDate: 2009-03-31', '1995-04-10'),
#  ('LASTAUTHENTICATIONDATE: 11-11-1982', '01-11-1996'),
#  ('dateofpurchase: 2015/06/26', '2019/02/26'),
#  ('Last Authentication Date: 25/05/2017', '31/12/1999'),
#  ('creationdate: June 12th, 2022', 'June 17th, 2022'),
#  ('MODIFIED_DATE: April 12th', 'May 9th'),
#  ('lastAuthenticationDate: 18th April', '12th June'),
#  ('lastAuthenticationDate: May 2nd', 'Feb 13th'),
#  ('lastAuthenticationDate: 6th Jan', '19th Jan'),
#  ('date of commencement: March 18, 2008', 'August 08, 2008'),
#  ('Date: 12 June 1991', '06 September 1991'),
#  ('Date_Of_Transaction: Nov 09, 2008', 'June 02, 2008'),
#  ('Published Date: 02 June 2003', '08 Aug 2003'),
#  ('Date-Of-Birth: 1995-03-14', '1989-08-10'),
#  ('TRANSACTION_DATE: 31-07-2018', '17-04-1983'),
#  ('END_DATE: 1989/10/05', '2009/10/11'),
#  ('end date: 17/05/1991', '17/07/1992'),
#  ('last_modified_date: January 21st, 2022', 'May 10th, 2022'),
#  ('rolecreateddate: January 28th', 'May 25th'),
#  ('Date-Of-Commencement: 13th June', '17th January'),
#  ('Date-Of-Commencement: Mar 29th', 'May 18th'),
#  ('Date-Of-Commencement: 19th Mar', '21st Mar'),
#  ('End Date: December 08, 2021', 'October 24, 2021'),
#  ('LAST MODIFIED DATE: 09 September 2001', '12 September 2001'),
#  ('LOGIN CREATED DATE: Apr 20, 1993', 'November 05, 1993'),
#  ('DATE OF TRANSACTION: 17 January 2004', '17 Aug 2004'),
#  ('Modified_Date: 2017-01-22', '2017-01-02'),
#  ('creationdate: 10-10-2019', '26-09-2008'),
#  ('ROLE CREATED DATE: 1984/10/12', '2010/07/27'),
#  ('Date-Of-Purchase: 31/10/1974', '12/01/1979'),
#  ('CREATION DATE: April 16th, 2022', 'April 21st, 2022'),
#  ('Role Created Date: February 23rd', 'March 9th'),
#  ('CREATION_DATE: 26th January', '15th April'),
#  ('CREATION_DATE: Mar 1st', 'Feb 12th'),
#  ('CREATION_DATE: 1st Mar', '6th Jan'),
#  ('last modified date: February 22, 1978', 'May 29, 1978'),
#  ('transactiondate: 14 February 2004', '15 September 2004'),
#  ('dateofpurchase: Jan 09, 2018', 'October 15, 2018'),
#  ('date_of_joining: 13 June 1976', '23 Sep 1976'),
#  ('Date_Of_Joining: 2001-09-02', '2006-05-20'),
#  ('LAST_AUTHENTICATION_DATE: 20-10-1990', '15-05-2003'),
#  ('publishedDate: 2017/03/21', '2002/05/07'),
#  ('Transaction-Date: 28/07/1973', '11/10/1975'),
#  ('DATE_OF_BIRTH: May 29th, 2022', 'April 26th, 2022'),
#  ('Role Created Date: May 11th', 'February 4th'),
#  ('DATE-OF-TRANSACTION: 25th April', '2nd May'),
#  ('DATE-OF-TRANSACTION: Feb 11th', 'May 15th'),
#  ('DATE-OF-TRANSACTION: 6th Feb', '7th Jun'),
#  ('end-date: February 19, 1979', 'August 09, 1979'),
#  ('Last Authentication Date: 18 December 1996', '16 February 1996'),
#  ('LASTMODIFIEDDATE: Feb 16, 1983', 'October 01, 1983'),
#  ('PUBLISHEDDATE: 03 October 1979', '29 Dec 1979'),
#  ('date_of_joining: 1975-10-04', '1974-07-06'),
#  ('Published Date: 25-05-2015', '02-12-1976'),
#  ('TRANSACTION-DATE: 2012/12/24', '2005/07/20'),
#  ('Role Created Date: 09/09/1990', '31/05/2002'),
#  ('date-of-transaction: March 31st, 2022', 'March 28th, 2022'),
#  ('PUBLISHEDDATE: May 19th', 'May 19th'),
#  ('DATE_OF_BIRTH: 16th January', '13th April'),
#  ('DATE_OF_BIRTH: Apr 20th', 'May 16th'),
#  ('DATE_OF_BIRTH: 11th Jun', '14th Apr'),
#  ('transaction-date: January 05, 1978', 'October 22, 1978'),
#  ('DateOfTransaction: 19 October 2018', '19 January 2018'),
#  ('publisheddate: Feb 10, 2016', 'July 31, 2016'),
#  ('LAST-AUTHENTICATION-DATE: 05 May 1971', '26 Jan 1971'),
#  ('creationDate: 2011-05-16', '2018-11-12'),
#  ('Date-Of-Birth: 18-12-2001', '09-01-2022'),
#  ('End Date: 1989/11/03', '1976/12/05'),
#  ('Modified Date: 20/05/1981', '16/07/2018'),
#  ('End_Date: February 12th, 2022', 'April 3rd, 2022'),
#  ('ModifiedDate: May 29th', 'April 12th'),
#  ('Creation-Date: 12th February', '20th February'),
#  ('Creation-Date: Mar 17th', 'Jun 13th'),
#  ('Creation-Date: 30th Jan', '7th Feb'),
#  ('Date_Of_Joining: March 30, 1983', 'February 20, 1983'),
#  ('dateOfJoining: 18 August 1992', '11 October 1992'),
#  ('date of birth: Sep 10, 2018', 'May 20, 2018'),
#  ('modified-date: 29 February 2015', '19 Dec 2015'),
#  ('date of commencement: 1979-10-14', '2006-10-15'),
#  ('End_Date: 29-05-1978', '10-09-1998'),
#  ('last modified date: 1976/11/29', '1979/07/21'),
#  ('dateofbirth: 15/07/2017', '14/06/2010'),
#  ('roleCreatedDate: January 24th, 2022', 'May 11th, 2022'),
#  ('endDate: January 1st', 'February 16th'),
#  ('ModifiedDate: 3rd April', '14th June'),
#  ('ModifiedDate: Jun 11th', 'Mar 31st'),
#  ('ModifiedDate: 29th Mar', '20th May'),
#  ('Modified Date: February 15, 2017', 'November 23, 2017'),
#  ('modifieddate: 14 April 1998', '28 May 1998'),
#  ('lastauthenticationdate: Jan 17, 1988', 'March 19, 1988'),
#  ('date_of_commencement: 26 July 1985', '15 Feb 1985'),
#  ('ROLE-CREATED-DATE: 2016-01-15', '1976-11-09'),
#  ('DATE OF JOINING: 23-05-2005', '31-12-1998'),
#  ('modifiedDate: 1988/07/09', '2016/01/21'),
#  ('LastAuthenticationDate: 12/04/2003', '01/05/2011'),
#  ('rolecreateddate: March 24th, 2022', 'June 5th, 2022'),
#  ('dateOfBirth: February 17th', 'March 31st'),
#  ('DATEOFBIRTH: 20th February', '24th May'),
#  ('DATEOFBIRTH: Feb 16th', 'May 31st'),
#  ('DATEOFBIRTH: 4th May', '14th Jan'),
#  ('date_of_purchase: May 29, 1984', 'January 05, 1984'),
#  ('DATE-OF-PURCHASE: 08 September 2005', '08 September 2005'),
#  ('date-of-transaction: Feb 27, 1993', 'October 25, 1993'),
#  ('DATE_OF_JOINING: 12 January 2006', '01 Jul 2006'),
#  ('DATE_OF_JOINING: 1987-05-27', '1973-11-01'),
#  ('Role-Created-Date: 21-06-1989', '11-08-2016'),
#  ('DateOfJoining: 1984/12/27', '1974/01/21'),
#  ('dateofbirth: 27/05/2015', '11/12/2019'),
#  ('dateofcommencement: February 25th, 2022', 'February 17th, 2022'),
#  ('Modified_Date: February 26th', 'March 16th'),
#  ('DATE_OF_PURCHASE: 11th February', '13th March'),
#  ('DATE_OF_PURCHASE: Feb 24th', 'May 23rd'),
#  ('DATE_OF_PURCHASE: 14th May', '2nd Jan'),
#  ('DATE OF JOINING: September 17, 2008', 'September 16, 2008'),
#  ('published date: 20 May 1986', '02 July 1986'),
#  ('Transaction-Date: Apr 08, 2003', 'June 12, 2003'),
#  ('date of commencement: 25 January 2015', '30 Jan 2015'),
#  ('transactionDate: 1994-09-18', '2003-06-26'),
#  ('end_date: 04-05-1976', '03-01-2007'),
#  ('date: 2001/02/15', '1993/05/19'),
#  ('Transaction-Date: 16/03/1978', '02/04/2001'),
#  ('date of purchase: March 17th, 2022', 'January 27th, 2022'),
#  ('End Date: April 13th', 'May 30th'),
#  ('Role_Created_Date: 1st June', '6th May'),
#  ('Role_Created_Date: Jun 18th', 'Apr 13th'),
#  ('Role_Created_Date: 31st May', '19th Mar'),
#  ('dateOfCommencement: May 18, 2011', 'June 30, 2011'),
#  ('Role-Created-Date: 08 March 1992', '23 December 1992'),
#  ('date of commencement: Dec 08, 1983', 'July 02, 1983'),
#  ('lastauthenticationdate: 21 December 2010', '29 Apr 2010'),
#  ('last_modified_date: 2014-08-10', '1995-04-05'),
#  ('Date Of Purchase: 23-09-2009', '18-12-2010'),
#  ('rolecreateddate: 1981/05/23', '2010/07/01'),
#  ('DATE_OF_COMMENCEMENT: 07/08/1994', '20/11/2000'),
#  ('role-created-date: May 9th, 2022', 'January 19th, 2022'),
#  ('creationdate: May 3rd', 'May 14th'),
#  ('ROLE_CREATED_DATE: 19th April', '13th February'),
#  ('ROLE_CREATED_DATE: Jan 21st', 'May 25th'),
#  ('ROLE_CREATED_DATE: 11th May', '3rd Jun'),
#  ('date-of-birth: October 15, 1983', 'May 14, 1983'),
#  ('Last Authentication Date: 26 October 2014', '13 January 2014'),
#  ('DateOfCommencement: Nov 17, 1980', 'October 07, 1980'),
#  ('Role-Created-Date: 18 October 1976', '21 Jul 1976'),
#  ('Last-Modified-Date: 2001-01-12', '1985-03-23'),
#  ('Published Date: 18-01-2021', '16-03-1978'),
#  ('Creation-Date: 2016/06/19', '1982/04/13'),
#  ('published_date: 09/10/1972', '17/10/2001'),
#  ('DATE-OF-PURCHASE: June 8th, 2022', 'January 31st, 2022'),
#  ('loginCreatedDate: June 5th', 'March 5th'),
#  ('date of commencement: 29th January', '24th May'),
#  ('date of commencement: Apr 19th', 'Apr 24th'),
#  ('date of commencement: 14th Jan', '14th Apr'),
#  ('date-of-purchase: December 18, 1993', 'February 30, 1993'),
#  ('DATE OF JOINING: 26 August 1977', '26 March 1977'),
#  ('LoginCreatedDate: May 14, 1975', 'October 18, 1975'),
#  ('DATE: 18 March 1986', '20 Apr 1986'),
#  ('date: 2015-06-28', '1999-06-27'),
#  ('DATEOFTRANSACTION: 17-05-1992', '20-05-1982'),
#  ('date: 1978/11/23', '2007/03/11'),
#  ('DATE-OF-PURCHASE: 04/12/2001', '13/04/1993'),
#  ('transaction date: May 24th, 2022', 'April 28th, 2022'),
#  ('modifieddate: April 13th', 'February 23rd'),
#  ('role created date: 1st February', '21st April'),
#  ('role created date: May 18th', 'Apr 28th'),
#  ('role created date: 2nd Apr', '9th Mar'),
#  ('LastAuthenticationDate: May 14, 2009', 'September 02, 2009'),
#  ('PUBLISHED-DATE: 25 March 1991', '01 July 1991'),
#  ('lastmodifieddate: Mar 25, 2002', 'December 27, 2002'),
#  ('DATE-OF-TRANSACTION: 25 June 2018', '26 Dec 2018'),
#  ('ROLECREATEDDATE: 2013-03-10', '2014-04-22'),
#  ('EndDate: 29-03-2011', '13-09-1971'),
#  ('LastModifiedDate: 1984/12/17', '1998/10/25'),
#  ('END DATE: 27/05/1979', '22/07/2011'),
#  ('End Date: June 16th, 2022', 'March 2nd, 2022'),
#  ('modifiedDate: April 25th', 'March 19th'),
#  ('Date_Of_Transaction: 22nd February', '9th February'),
#  ('Date_Of_Transaction: Apr 2nd', 'Apr 30th'),
#  ('Date_Of_Transaction: 15th May', '27th Feb'),
#  ('LOGIN CREATED DATE: February 30, 1970', 'July 09, 1970'),
#  ('LAST MODIFIED DATE: 06 December 2006', '10 January 2006'),
#  ('TRANSACTION_DATE: Jan 22, 2003', 'February 16, 2003'),
#  ('date of commencement: 26 January 1998', '02 Dec 1998'),
#  ('EndDate: 2011-04-03', '1976-06-06'),
#  ('DATE OF PURCHASE: 11-03-1989', '11-08-1973'),
#  ('dateOfBirth: 1987/01/17', '2007/05/17'),
#  ('Date Of Transaction: 13/04/1976', '15/11/1988'),
#  ('DATE-OF-COMMENCEMENT: May 2nd, 2022', 'March 5th, 2022'),
#  ('TRANSACTION-DATE: February 21st', 'February 25th'),
#  ('DATE OF PURCHASE: 11th January', '4th March'),
#  ('DATE OF PURCHASE: Feb 26th', 'Mar 15th'),
#  ('DATE OF PURCHASE: 10th Feb', '6th May'),
#  ('ROLE-CREATED-DATE: January 09, 1997', 'November 04, 1997'),
#  ('last_authentication_date: 27 February 2018', '05 August 2018'),
#  ('DateOfBirth: Jun 04, 1996', 'April 27, 1996'),
#  ('Date-Of-Birth: 06 October 2006', '05 Feb 2006'),
#  ('transaction date: 2010-11-17', '2004-07-23'),
#  ('MODIFIED-DATE: 11-09-2014', '05-12-1987'),
#  ('DateOfBirth: 2011/12/29', '2010/06/04'),
#  ('Last Authentication Date: 08/02/2018', '15/12/2006'),
#  ('login-created-date: May 10th, 2022', 'January 17th, 2022'),
#  ('dateofbirth: April 23rd', 'February 28th'),
#  ('lastmodifieddate: 30th March', '3rd February'),
#  ('lastmodifieddate: May 28th', 'Feb 25th'),
#  ('lastmodifieddate: 17th May', '21st May'),
#  ('Date_Of_Transaction: July 14, 2019', 'December 17, 2019'),
#  ('lastModifiedDate: 13 July 2007', '15 January 2007'),
#  ('lastmodifieddate: Aug 21, 1990', 'July 20, 1990'),
#  ('modifieddate: 05 November 2019', '11 Nov 2019'),
#  ('Creation-Date: 1986-12-02', '1977-12-26'),
#  ('LAST MODIFIED DATE: 02-06-1997', '19-04-2015'),
#  ('date-of-purchase: 2009/11/07', '2002/03/09'),
#  ('End_Date: 23/08/1975', '26/12/2018'),
#  ('roleCreatedDate: February 19th, 2022', 'March 8th, 2022'),
#  ('LAST-MODIFIED-DATE: March 1st', 'May 9th'),
#  ('Transaction Date: 25th January', '21st March'),
#  ('Transaction Date: Jun 6th', 'Apr 9th'),
#  ('Transaction Date: 17th Jan', '7th Jan'),
#  ('LAST MODIFIED DATE: February 07, 1995', 'September 01, 1995'),
#  ('DATE OF PURCHASE: 29 April 2018', '24 October 2018'),
#  ('creation date: Jan 16, 1985', 'August 25, 1985'),
#  ('MODIFIED_DATE: 03 December 2007', '07 Jul 2007'),
#  ('rolecreateddate: 2004-02-19', '1973-07-29'),
#  ('role-created-date: 12-03-1990', '04-04-1978'),
#  ('enddate: 1974/02/25', '1991/06/10'),
#  ('DateOfJoining: 15/03/1988', '05/12/2003'),
#  ('login_created_date: April 24th, 2022', 'April 15th, 2022'),
#  ('creation_date: January 18th', 'January 18th'),
#  ('enddate: 29th January', '3rd March'),
#  ('enddate: Jun 10th', 'May 21st'),
#  ('enddate: 12th Jun', '25th Feb'),
#  ('date_of_commencement: November 13, 1975', 'October 15, 1975'),
#  ('DATEOFBIRTH: 22 August 1999', '10 December 1999'),
#  ('creationDate: Oct 11, 2008', 'October 02, 2008'),
#  ('date-of-purchase: 09 March 1998', '17 Jan 1998'),
#  ('published-date: 2021-11-23', '1979-09-25'),
#  ('LAST-AUTHENTICATION-DATE: 11-09-1975', '14-02-1988'),
#  ('dateoftransaction: 2004/03/16', '1993/12/22'),
#  ('transaction-date: 21/10/1995', '16/11/2012'),
#  ('Date-Of-Purchase: April 27th, 2022', 'January 26th, 2022'),
#  ('publisheddate: February 22nd', 'March 12th'),
#  ('date of joining: 2nd May', '15th June'),
#  ('date of joining: Apr 28th', 'Jun 11th'),
#  ('date of joining: 29th Apr', '19th Apr'),
#  ('ROLE_CREATED_DATE: October 29, 2002', 'December 31, 2002'),
#  ('publisheddate: 05 March 1980', '22 November 1980'),
#  ('dateOfCommencement: Sep 20, 2021', 'February 10, 2021'),
#  ('CREATION-DATE: 09 January 1981', '23 Nov 1981'),
#  ('lastModifiedDate: 1977-07-03', '2004-04-22'),
#  ('Login-Created-Date: 10-11-1992', '05-11-2006'),
#  ('date_of_commencement: 1984/12/23', '2000/06/01'),
#  ('DATEOFTRANSACTION: 26/08/1997', '09/08/2011'),
#  ('transaction date: April 8th, 2022', 'June 12th, 2022'),
#  ('last-authentication-date: May 15th', 'February 8th'),
#  ('LastAuthenticationDate: 30th May', '14th June'),
#  ('LastAuthenticationDate: Mar 4th', 'Apr 19th'),
#  ('LastAuthenticationDate: 14th Feb', '8th Jun'),
#  ('DATEOFCOMMENCEMENT: January 10, 2013', 'September 15, 2013'),
#  ('dateofpurchase: 17 July 1982', '08 June 1982'),
#  ('DATE OF COMMENCEMENT: Sep 16, 2016', 'December 03, 2016'),
#  ('LAST AUTHENTICATION DATE: 04 November 2001', '23 Jun 2001'),
#  ('logincreateddate: 1976-02-15', '1991-09-30'),
#  ('DATE_OF_TRANSACTION: 08-01-1982', '23-10-1999'),
#  ('modifieddate: 1985/09/17', '2001/09/30'),
#  ('Role Created Date: 21/09/1996', '21/10/2004'),
#  ('role created date: April 19th, 2022', 'May 29th, 2022'),
#  ('modified date: May 31st', 'January 24th'),
#  ('date-of-transaction: 3rd March', '23rd February'),
#  ('date-of-transaction: May 8th', 'Jun 1st'),
#  ('date-of-transaction: 25th Apr', '10th Feb'),
#  ('ROLE CREATED DATE: February 15, 2007', 'February 07, 2007'),
#  ('DATE OF JOINING: 22 May 1997', '19 December 1997'),
#  ('Login Created Date: May 23, 2005', 'June 19, 2005'),
#  ('date-of-commencement: 23 March 2017', '12 Oct 2017'),
#  ('Login-Created-Date: 1978-05-11', '2003-01-20'),
#  ('End-Date: 11-03-2017', '20-04-2011'),
#  ('date-of-commencement: 2006/02/05', '2009/01/02'),
#  ('Date-Of-Birth: 09/04/1976', '07/06/1993'),
#  ('Date Of Birth: March 29th, 2022', 'January 19th, 2022'),
#  ('Date-Of-Birth: May 27th', 'April 2nd'),
#  ('Date Of Commencement: 24th January', '18th May'),
#  ('Date Of Commencement: Feb 6th', 'May 25th'),
#  ('Date Of Commencement: 5th Feb', '21st Feb'),
#  ('Published_Date: August 03, 1996', 'November 17, 1996'),
#  ('Role Created Date: 11 July 1980', '04 April 1980'),
#  ('Creation-Date: May 18, 1976', 'March 08, 1976'),
#  ('Date_Of_Transaction: 14 April 2008', '18 Feb 2008'),
#  ('END-DATE: 2014-11-25', '2021-09-07'),
#  ('date_of_transaction: 15-07-1981', '24-03-1980'),
#  ('CREATION-DATE: 2006/01/12', '1980/08/11'),
#  ('Date Of Commencement: 31/05/2011', '06/04/2005'),
#  ('Login_Created_Date: January 16th, 2022', 'June 17th, 2022'),
#  ('LOGIN CREATED DATE: May 18th', 'June 13th'),
#  ('Last-Authentication-Date: 20th January', '27th February'),
#  ('Last-Authentication-Date: Feb 6th', 'Jan 23rd'),
#  ('Last-Authentication-Date: 27th Apr', '5th Apr'),
#  ('role created date: February 31, 2005', 'October 24, 2005'),
#  ('LOGINCREATEDDATE: 12 April 1979', '20 July 1979'),
#  ('date of purchase: Dec 04, 1971', 'October 11, 1971'),
#  ('role-created-date: 24 October 2010', '21 Nov 2010'),
#  ('CREATIONDATE: 1990-08-09', '1989-02-21'),
#  ('Role Created Date: 07-10-1993', '04-07-2002'),
#  ('date of purchase: 1997/12/25', '1981/10/22'),
#  ('END-DATE: 17/03/1992', '25/08/2003'),
#  ('date-of-purchase: March 7th, 2022', 'January 5th, 2022'),
#  ('Role_Created_Date: February 23rd', 'January 10th'),
#  ('CREATIONDATE: 17th March', '3rd May'),
#  ('CREATIONDATE: Jan 24th', 'Jan 21st'),
#  ('CREATIONDATE: 13th May', '2nd Apr'),
#  ('END_DATE: October 19, 1977', 'January 14, 1977'),
#  ('Creation_Date: 28 July 1994', '06 October 1994'),
#  ('Date-Of-Birth: Jan 15, 1993', 'November 16, 1993'),
#  ('DATE-OF-BIRTH: 08 October 1971', '05 Sep 1971'),
#  ('date-of-purchase: 1987-05-30', '1998-02-15'),
#  ('Last_Authentication_Date: 26-02-1995', '12-06-2001'),
#  ('DATE OF PURCHASE: 1984/03/28', '1983/09/30'),
#  ('last_authentication_date: 25/06/1983', '21/11/1995'),
#  ('TRANSACTION DATE: March 17th, 2022', 'March 31st, 2022'),
#  ('Date_Of_Birth: May 6th', 'May 10th'),
#  ('roleCreatedDate: 25th February', '6th May'),
#  ('roleCreatedDate: Feb 16th', 'Apr 22nd'),
#  ('roleCreatedDate: 26th Feb', '2nd Jan'),
#  ('Role Created Date: January 13, 1996', 'July 03, 1996'),
#  ('Last_Authentication_Date: 29 October 1973', '02 August 1973'),
#  ('LAST-AUTHENTICATION-DATE: Feb 09, 2017', 'November 25, 2017'),
#  ('role-created-date: 18 November 1987', '09 Jun 1987'),
#  ('PUBLISHED_DATE: 1990-03-22', '1996-12-05'),
#  ('published_date: 22-08-1999', '03-05-2004'),
#  ('TRANSACTIONDATE: 1992/08/30', '2018/06/02'),
#  ('ROLECREATEDDATE: 17/11/1995', '16/04/1992'),
#  ('Role-Created-Date: May 5th, 2022', 'February 20th, 2022'),
#  ('LASTMODIFIEDDATE: February 12th', 'March 17th'),
#  ('TRANSACTION-DATE: 5th January', '18th February'),
#  ('TRANSACTION-DATE: Apr 6th', 'May 2nd'),
#  ('TRANSACTION-DATE: 8th May', '22nd May'),
#  ('creationDate: October 14, 2004', 'January 01, 2004'),
#  ('Date_Of_Purchase: 09 May 1985', '21 May 1985'),
#  ('date_of_purchase: Dec 13, 1985', 'June 06, 1985'),
#  ('last authentication date: 24 September 2021', '11 Mar 2021'),
#  ('TRANSACTIONDATE: 2003-01-04', '1980-12-03'),
#  ('LAST-MODIFIED-DATE: 08-08-2019', '13-12-1971'),
#  ('RoleCreatedDate: 1977/03/10', '1982/03/28'),
#  ('MODIFIEDDATE: 29/12/2005', '08/07/2001'),
#  ('LOGINCREATEDDATE: February 23rd, 2022', 'February 5th, 2022'),
#  ('modified date: January 27th', 'June 16th'),
#  ('modifiedDate: 28th February', '27th February'),
#  ('modifiedDate: May 3rd', 'Apr 9th'),
#  ('modifiedDate: 11th Mar', '24th Mar'),
#  ('modifieddate: June 26, 1982', 'August 24, 1982'),
#  ('creationdate: 31 March 1987', '03 January 1987'),
#  ('DATEOFJOINING: Sep 24, 2017', 'August 03, 2017'),
#  ('ROLE CREATED DATE: 04 February 2011', '28 Jul 2011'),
#  ('login created date: 2010-08-18', '1992-10-19'),
#  ('LOGIN-CREATED-DATE: 21-12-2014', '05-02-1972'),
#  ('DateOfBirth: 1987/11/15', '2011/07/18'),
#  ('DATE_OF_COMMENCEMENT: 12/11/1997', '24/06/2014'),
#  ('EndDate: May 15th, 2022', 'February 8th, 2022'),
#  ('LOGIN-CREATED-DATE: April 13th', 'May 13th'),
#  ('logincreateddate: 12th February', '5th March'),
#  ('logincreateddate: May 20th', 'May 28th'),
#  ('logincreateddate: 8th Jan', '27th Jan'),
#  ('Transaction-Date: April 28, 2004', 'February 10, 2004'),
#  ('CREATIONDATE: 25 November 2021', '18 August 2021'),
#  ('Date_Of_Joining: Mar 17, 1981', 'February 11, 1981'),
#  ('ModifiedDate: 16 March 1996', '18 Dec 1996'),
#  ('endDate: 2013-04-19', '2001-12-17'),
#  ('date-of-birth: 23-01-2021', '24-10-1992'),
#  ('End-Date: 1974/06/06', '2012/04/04'),
#  ('MODIFIED DATE: 15/06/1984', '01/05/2008'),
#  ('date_of_joining: January 4th, 2022', 'March 4th, 2022'),
#  ('LASTMODIFIEDDATE: January 27th', 'February 14th'),
#  ('Creation-Date: 7th January', '11th May'),
#  ('Creation-Date: Mar 1st', 'Feb 27th'),
#  ('Creation-Date: 6th Jun', '3rd Jun'),
#  ('logincreateddate: March 15, 1978', 'November 28, 1978'),
#  ('DateOfBirth: 26 August 2017', '04 February 2017'),
#  ('roleCreatedDate: Aug 22, 2005', 'April 16, 2005'),
#  ('Last-Authentication-Date: 25 September 2013', '02 Oct 2013'),
#  ('date_of_purchase: 1977-03-14', '1993-08-12'),
#  ('transactionDate: 20-03-1983', '16-09-1984'),
#  ('dateOfPurchase: 2006/02/07', '1997/04/03'),
#  ('Creation_Date: 08/11/1990', '18/06/1983'),
#  ('Last_Authentication_Date: March 18th, 2022', 'April 26th, 2022'),
#  ('lastauthenticationdate: April 26th', 'February 25th'),
#  ('role_created_date: 11th February', '2nd March'),
#  ('role_created_date: May 3rd', 'Apr 11th'),
#  ('role_created_date: 12th Jun', '12th Jun'),
#  ('date-of-transaction: November 21, 2006', 'November 08, 2006'),
#  ('date of purchase: 24 April 1990', '03 September 1990'),
#  ('TRANSACTION DATE: Sep 14, 1980', 'May 16, 1980'),
#  ('EndDate: 05 July 1994', '07 May 1994'),
#  ('MODIFIED_DATE: 2010-02-27', '1991-09-20'),
#  ('DATE-OF-BIRTH: 07-07-2002', '01-10-2006'),
#  ('role created date: 1994/10/23', '1980/02/15'),
#  ('DATE-OF-PURCHASE: 26/10/1994', '16/04/1980'),
#  ('Creation_Date: March 3rd, 2022', 'May 20th, 2022'),
#  ('date-of-birth: February 19th', 'March 18th'),
#  ('Transaction_Date: 22nd February', '3rd January'),
#  ('Transaction_Date: Jan 28th', 'Apr 30th'),
#  ('Transaction_Date: 2nd Mar', '14th Feb'),
#  ('End_Date: January 25, 1986', 'May 16, 1986'),
#  ('LAST-MODIFIED-DATE: 30 October 1989', '01 November 1989'),
#  ('Transaction Date: Apr 20, 2000', 'December 03, 2000'),
#  ('Date_Of_Joining: 09 December 2014', '06 Aug 2014'),
#  ('Date-Of-Transaction: 1973-09-07', '1987-01-22'),
#  ('Date_Of_Joining: 10-02-2017', '07-01-2002'),
#  ('lastAuthenticationDate: 1986/05/02', '2020/10/14'),
#  ('ENDDATE: 11/05/1999', '23/09/1981'),
#  ('date_of_birth: February 27th, 2022', 'May 18th, 2022'),
#  ('dateOfCommencement: May 14th', 'April 9th'),
#  ('DATEOFTRANSACTION: 29th January', '13th January'),
#  ('DATEOFTRANSACTION: Mar 31st', 'Jan 12th'),
#  ('DATEOFTRANSACTION: 5th May', '19th May'),
#  ('End Date: March 16, 1982', 'April 20, 1982'),
#  ('last_modified_date: 22 May 1988', '14 February 1988'),
#  ('date of commencement: Feb 01, 2011', 'July 17, 2011'),
#  ('PUBLISHEDDATE: 22 August 1978', '23 May 1978'),
#  ('creation_date: 1980-09-02', '2014-10-25'),
#  ('lastmodifieddate: 30-10-1979', '21-08-1991'),
#  ('login-created-date: 2004/10/11', '2011/05/21'),
#  ('DateOfTransaction: 27/12/1971', '15/02/2012'),
#  ('DATE: January 12th, 2022', 'April 17th, 2022'),
#  ('Date Of Birth: April 10th', 'January 17th'),
#  ('LOGIN-CREATED-DATE: 25th March', '6th June'),
#  ('LOGIN-CREATED-DATE: Apr 13th', 'Feb 13th'),
#  ('LOGIN-CREATED-DATE: 4th May', '11th Apr'),
#  ('date-of-birth: August 19, 2015', 'December 07, 2015'),
#  ('LAST_AUTHENTICATION_DATE: 06 October 1998', '02 December 1998'),
#  ('DateOfPurchase: Sep 24, 1992', 'April 12, 1992'),
#  ('Date-Of-Commencement: 01 March 2008', '05 Jul 2008'),
#  ('MODIFIED_DATE: 1996-12-13', '1986-02-08'),
#  ('Role_Created_Date: 20-06-1996', '11-05-2016'),
#  ('date_of_commencement: 1992/03/19', '1987/05/12'),
#  ('DATE_OF_TRANSACTION: 19/06/2011', '26/03/1996'),
#  ('LAST_MODIFIED_DATE: February 26th, 2022', 'May 15th, 2022'),
#  ('End Date: January 23rd', 'February 22nd'),
#  ('date-of-birth: 24th April', '15th April'),
#  ('date-of-birth: May 20th', 'May 4th'),
#  ('date-of-birth: 4th Feb', '25th Jan'),
#  ('LastAuthenticationDate: March 26, 1987', 'April 30, 1987'),
#  ('Login_Created_Date: 11 October 2003', '17 February 2003'),
#  ('CreationDate: Jul 06, 1984', 'May 21, 1984'),
#  ('dateofbirth: 07 June 1980', '29 Feb 1980'),
#  ('last_modified_date: 1998-07-15', '1985-06-02'),
#  ('login_created_date: 15-01-1976', '22-01-1991'),
#  ('Role_Created_Date: 1984/03/25', '1986/04/07'),
#  ('TRANSACTIONDATE: 12/12/2015', '16/12/1991'),
#  ('rolecreateddate: January 7th, 2022', 'March 28th, 2022'),
#  ('dateOfPurchase: March 31st', 'January 5th'),
#  ('DATE-OF-JOINING: 5th May', '9th March'),
#  ('DATE-OF-JOINING: Apr 7th', 'Feb 9th'),
#  ('DATE-OF-JOINING: 8th Jun', '3rd May'),
#  ('DateOfCommencement: November 20, 2018', 'December 14, 2018'),
#  ('DATEOFTRANSACTION: 11 October 1990', '02 May 1990'),
#  ('Creation-Date: Dec 18, 2021', 'February 20, 2021'),
#  ('LastAuthenticationDate: 06 February 1998', '30 Apr 1998'),
#  ('DATE_OF_COMMENCEMENT: 1995-07-19', '1994-08-06'),
#  ('CreationDate: 23-04-1998', '26-07-2009'),
#  ('Login-Created-Date: 1977/02/05', '1990/11/30'),
#  ('login-created-date: 06/09/1980', '18/08/1979'),
#  ('last authentication date: January 17th, 2022', 'May 21st, 2022'),
#  ('Date_Of_Joining: February 26th', 'April 30th'),
#  ('Date_Of_Joining: 11th January', '2nd March'),
#  ('Date_Of_Joining: Apr 16th', 'Jan 2nd'),
#  ('Date_Of_Joining: 20th Jun', '13th Jan'),
#  ('Date_Of_Commencement: September 05, 2017', 'November 13, 2017'),
#  ('DateOfJoining: 27 December 1971', '14 October 1971'),
#  ('Last-Authentication-Date: May 17, 2009', 'April 28, 2009'),
#  ('last-modified-date: 22 August 1990', '02 Jan 1990'),
#  ('DateOfPurchase: 1972-02-06', '1997-11-03'),
#  ('Modified-Date: 16-07-2015', '23-03-1990'),
#  ('ROLE CREATED DATE: 2012/11/21', '2016/11/08'),
#  ('last_authentication_date: 07/03/1993', '07/12/1972'),
#  ('TRANSACTION DATE: April 27th, 2022', 'April 28th, 2022'),
#  ('TRANSACTIONDATE: February 1st', 'May 3rd'),
#  ('lastAuthenticationDate: 16th February', '30th January'),
#  ('lastAuthenticationDate: Apr 3rd', 'Mar 12th'),
#  ('lastAuthenticationDate: 7th Jan', '18th Feb'),
#  ('DateOfCommencement: April 07, 1981', 'June 16, 1981'),
#  ('date of joining: 11 November 1988', '27 May 1988'),
#  ('PUBLISHEDDATE: May 27, 1972', 'February 23, 1972'),
#  ('dateOfBirth: 19 May 1994', '05 Jan 1994'),
#  ('DateOfJoining: 1998-07-26', '2013-05-27'),
#  ('Date Of Purchase: 10-11-1991', '06-07-1976'),
#  ('Modified-Date: 2008/12/09', '2017/08/07'),
#  ('PUBLISHEDDATE: 09/01/1993', '16/04/2004'),
#  ('last-modified-date: March 23rd, 2022', 'March 26th, 2022'),
#  ('LAST-AUTHENTICATION-DATE: May 26th', 'March 21st'),
#  ('DATEOFJOINING: 16th June', '3rd April'),
#  ('DATEOFJOINING: Mar 11th', 'Apr 27th'),
#  ('DATEOFJOINING: 13th Apr', '10th May'),
#  ('ROLE-CREATED-DATE: July 10, 1982', 'June 09, 1982'),
#  ('MODIFIED-DATE: 07 September 2007', '26 February 2007'),
#  ('PublishedDate: Oct 12, 2011', 'December 19, 2011'),
#  ('DATEOFJOINING: 04 April 1982', '27 Sep 1982'),
#  ('endDate: 1972-07-10', '1987-06-21'),
#  ('DATE_OF_BIRTH: 11-11-1989', '18-03-1971'),
#  ('ROLE_CREATED_DATE: 1997/12/05', '1975/10/11'),
#  ('TRANSACTION DATE: 07/11/1978', '21/06/2021'),
#  ('Date Of Purchase: June 15th, 2022', 'February 15th, 2022'),
#  ('Date_Of_Joining: March 16th', 'February 27th'),
#  ('date_of_transaction: 4th March', '8th January'),
#  ('date_of_transaction: Jun 12th', 'Feb 6th'),
#  ('date_of_transaction: 7th Mar', '27th Apr'),
#  ('last_authentication_date: October 01, 2012', 'May 22, 2012'),
#  ('enddate: 15 October 2002', '27 January 2002'),
#  ('date of joining: May 07, 2015', 'October 30, 2015'),
#  ('CREATIONDATE: 10 December 1975', '25 May 1975'),
#  ('Last Modified Date: 1986-09-16', '2019-05-05'),
#  ('Creation_Date: 18-02-1987', '02-02-1973'),
#  ('publishedDate: 1979/01/30', '2003/01/30'),
#  ('date of commencement: 04/08/1997', '12/04/2019'),
#  ('DATE OF BIRTH: April 1st, 2022', 'February 28th, 2022'),
#  ('published_date: April 28th', 'June 6th'),
#  ('last-modified-date: 16th April', '12th May'),
#  ('last-modified-date: May 15th', 'Feb 8th'),
#  ('last-modified-date: 4th Jan', '7th May'),
#  ('LOGIN_CREATED_DATE: November 30, 2019', 'March 11, 2019'),
#  ('DATEOFPURCHASE: 01 January 1995', '26 April 1995'),
#  ('DATE_OF_COMMENCEMENT: Apr 27, 1987', 'August 11, 1987'),
#  ('Date: 30 September 1974', '07 Sep 1974'),
#  ('date of joining: 2005-02-22', '2021-11-15'),
#  ('MODIFIED_DATE: 31-05-1982', '07-03-2004'),
#  ('rolecreateddate: 1972/01/06', '1999/02/24'),
#  ('DATE_OF_BIRTH: 07/03/2020', '01/06/1974'),
#  ('modifiedDate: June 15th, 2022', 'May 7th, 2022'),
#  ('publisheddate: February 6th', 'June 8th'),
#  ('Last-Authentication-Date: 15th February', '28th April'),
#  ('Last-Authentication-Date: Mar 17th', 'Jan 18th'),
#  ('Last-Authentication-Date: 16th Apr', '14th Apr'),
#  ('last-modified-date: September 13, 2007', 'October 25, 2007'),
#  ('DateOfBirth: 24 December 1994', '27 January 1994'),
#  ('Last_Modified_Date: Apr 24, 2008', 'September 29, 2008'),
#  ('ROLE CREATED DATE: 04 August 2005', '13 Oct 2005'),
#  ('DATEOFBIRTH: 1989-12-26', '1999-09-18'),
#  ('date_of_joining: 27-05-2009', '05-02-1991'),
#  ('DateOfTransaction: 2006/07/28', '1976/08/14'),
#  ('LAST AUTHENTICATION DATE: 08/11/1988', '01/01/1975'),
#  ('login created date: January 15th, 2022', 'May 29th, 2022'),
#  ('EndDate: January 8th', 'March 11th'),
#  ('CREATION_DATE: 10th May', '24th May'),
#  ('CREATION_DATE: Feb 19th', 'Mar 28th'),
#  ('CREATION_DATE: 24th Apr', '22nd May'),
#  ('TRANSACTION DATE: April 04, 1999', 'April 13, 1999'),
#  ('MODIFIED DATE: 01 September 2001', '02 January 2001'),
#  ('ENDDATE: Jun 02, 1972', 'October 21, 1972'),
#  ('MODIFIED-DATE: 28 June 1997', '24 Apr 1997'),
#  ('Modified-Date: 1976-01-23', '2021-06-30'),
#  ('DATEOFBIRTH: 01-05-1971', '21-05-2000'),
#  ('ENDDATE: 1974/05/31', '1976/11/02'),
#  ('Date_Of_Commencement: 26/07/2020', '11/03/1970'),
#  ('PUBLISHEDDATE: January 12th, 2022', 'March 13th, 2022'),
#  ('LoginCreatedDate: March 26th', 'April 1st'),
#  ('Date_Of_Birth: 19th February', '18th April'),
#  ('Date_Of_Birth: Mar 22nd', 'Feb 27th'),
#  ('Date_Of_Birth: 4th May', '19th Mar'),
#  ('MODIFIED-DATE: December 10, 1971', 'May 07, 1971'),
#  ('LASTMODIFIEDDATE: 10 July 2018', '14 February 2018'),
#  ('date-of-commencement: Aug 11, 1992', 'January 31, 1992'),
#  ('DATE-OF-JOINING: 12 December 2020', '31 Sep 2020'),
#  ('transactiondate: 1971-09-21', '1988-10-28'),
#  ('DATE OF JOINING: 09-06-1982', '09-02-1983'),
#  ('CREATION-DATE: 1976/02/27', '1997/01/02'),
#  ('creation date: 22/11/2018', '14/11/1983'),
#  ('LAST-MODIFIED-DATE: June 15th, 2022', 'March 19th, 2022'),
#  ('MODIFIEDDATE: May 12th', 'April 30th'),
#  ('Published-Date: 22nd April', '27th May'),
#  ('Published-Date: May 25th', 'Apr 29th'),
#  ('Published-Date: 27th May', '30th Jan'),
#  ('Last Modified Date: November 25, 2011', 'July 10, 2011'),
#  ('ROLE-CREATED-DATE: 18 June 2005', '09 May 2005'),
#  ('rolecreateddate: Aug 21, 1979', 'December 17, 1979'),
#  ('LASTMODIFIEDDATE: 07 June 2002', '13 Mar 2002'),
#  ('PUBLISHED-DATE: 1971-02-14', '2009-02-13'),
#  ('date-of-joining: 29-05-2021', '19-03-2022'),
#  ('Last_Modified_Date: 1998/07/17', '2015/10/13'),
#  ('date_of_joining: 01/08/2008', '06/10/1997'),
#  ('ROLE CREATED DATE: April 9th, 2022', 'February 26th, 2022'),
#  ('published date: May 18th', 'June 10th'),
#  ('logincreateddate: 18th June', '22nd May'),
#  ('logincreateddate: Jan 30th', 'Jan 2nd'),
#  ('logincreateddate: 24th May', '16th Feb'),
#  ('Modified-Date: November 12, 2011', 'August 24, 2011'),
#  ('DATE_OF_PURCHASE: 17 February 2012', '04 March 2012'),
#  ('last-authentication-date: Dec 21, 2003', 'August 12, 2003'),
#  ('End Date: 28 January 1981', '15 Feb 1981'),
#  ('login-created-date: 1999-02-26', '2015-02-23'),
#  ('Date Of Transaction: 12-02-1986', '15-10-2000'),
#  ('MODIFIEDDATE: 1983/04/02', '1976/07/27'),
#  ('Modified_Date: 11/12/1985', '14/08/2018'),
#  ('creation_date: January 4th, 2022', 'February 7th, 2022'),
#  ('LAST_MODIFIED_DATE: March 15th', 'March 26th'),
#  ('LAST-MODIFIED-DATE: 8th February', '14th April'),
#  ('LAST-MODIFIED-DATE: May 19th', 'May 14th'),
#  ('LAST-MODIFIED-DATE: 24th Apr', '29th Mar'),
#  ('MODIFIED_DATE: February 08, 2004', 'September 09, 2004'),
#  ('role-created-date: 15 February 1971', '23 November 1971'),
#  ('Date-Of-Birth: Mar 26, 2006', 'May 26, 2006'),
#  ('ModifiedDate: 29 September 2001', '06 Nov 2001'),
#  ('TRANSACTIONDATE: 2019-03-01', '2020-03-07'),
#  ('lastmodifieddate: 31-08-2005', '22-04-2005'),
#  ('End_Date: 2003/01/19', '1997/10/29'),
#  ('ModifiedDate: 16/03/2002', '17/12/1976'),
#  ('MODIFIED DATE: May 20th, 2022', 'January 24th, 2022'),
#  ('Date_Of_Commencement: May 11th', 'January 25th'),
#  ('LastAuthenticationDate: 29th January', '7th April'),
#  ('LastAuthenticationDate: Apr 23rd', 'Jan 29th'),
#  ('LastAuthenticationDate: 15th Apr', '18th Apr'),
#  ('Published_Date: December 24, 2019', 'November 10, 2019'),
#  ('last_authentication_date: 25 May 2014', '13 October 2014'),
#  ('creationdate: Nov 17, 1970', 'November 19, 1970'),
#  ('ROLECREATEDDATE: 28 November 1989', '10 Nov 1989'),
#  ('DATE-OF-COMMENCEMENT: 1974-07-27', '1977-03-07'),
#  ('LOGIN CREATED DATE: 10-09-1982', '15-06-1975'),
#  ('LOGIN-CREATED-DATE: 1990/02/15', '2011/02/26'),
#  ('Modified Date: 06/03/2006', '06/06/1989'),
#  ('LOGIN CREATED DATE: April 4th, 2022', 'January 31st, 2022'),
#  ('published date: March 23rd', 'May 19th'),
#  ('dateofbirth: 21st January', '7th June'),
#  ('dateofbirth: May 15th', 'Jan 8th'),
#  ('dateofbirth: 24th Mar', '6th Apr'),
#  ('dateofbirth: August 27, 2002', 'March 13, 2002'),
#  ('last modified date: 31 December 1978', '31 October 1978'),
#  ('Published_Date: Jun 07, 2013', 'September 01, 2013'),
#  ('dateofcommencement: 17 December 1979', '30 Jun 1979'),
#  ('Transaction Date: 1971-06-01', '2015-03-05'),
#  ('DATE-OF-COMMENCEMENT: 23-07-1995', '07-08-2000'),
#  ('login-created-date: 1979/01/02', '1979/08/26'),
#  ('role-created-date: 09/10/1979', '14/01/2015'),
#  ('Modified Date: May 4th, 2022', 'April 12th, 2022'),
#  ('Login Created Date: May 31st', 'April 27th'),
#  ('DATE_OF_COMMENCEMENT: 28th January', '23rd February'),
#  ('DATE_OF_COMMENCEMENT: Mar 15th', 'May 5th'),
#  ('DATE_OF_COMMENCEMENT: 28th Apr', '24th Feb'),
#  ('DATE: April 23, 2018', 'January 09, 2018'),
#  ('transaction date: 06 February 2011', '20 May 2011'),
#  ('modified-date: Oct 24, 2012', 'August 06, 2012'),
#  ('date-of-birth: 25 September 1996', '10 Aug 1996'),
#  ('transaction date: 1993-05-13', '2007-09-28'),
#  ('LAST MODIFIED DATE: 09-01-1986', '20-12-2020'),
#  ('Transaction Date: 2004/11/22', '1975/12/10'),
#  ('CreationDate: 10/05/2004', '02/12/1977'),
#  ('last_modified_date: May 12th, 2022', 'April 15th, 2022'),
#  ('modified_date: January 17th', 'March 6th'),
#  ('date: 16th May', '10th April'),
#  ('date: Jun 13th', 'May 12th'),
#  ('date: 16th Feb', '27th May'),
#  ('DATE-OF-PURCHASE: April 15, 2002', 'August 30, 2002'),
#  ('Last-Authentication-Date: 11 November 1998', '26 September 1998'),
#  ('login_created_date: Jun 09, 1995', 'August 21, 1995'),
#  ('published date: 21 June 2006', '27 Jul 2006'),
#  ('Last-Modified-Date: 1974-04-25', '2021-10-14'),
#  ('DATEOFBIRTH: 12-08-1989', '20-10-2004'),
#  ('Date Of Purchase: 2003/12/26', '1991/03/24'),
#  ('date-of-commencement: 22/05/2010', '09/07/1974'),
#  ('date_of_commencement: March 24th, 2022', 'February 17th, 2022'),
#  ('Last_Modified_Date: January 7th', 'May 25th'),
#  ('Published Date: 23rd February', '11th May'),
#  ('Published Date: Feb 13th', 'May 31st'),
#  ('Published Date: 3rd Jan', '19th Jun'),
#  ('DATE_OF_JOINING: May 18, 2010', 'August 08, 2010'),
#  ('lastauthenticationdate: 19 August 2005', '17 February 2005'),
#  ('LAST_AUTHENTICATION_DATE: Sep 08, 1988', 'August 01, 1988'),
#  ('lastModifiedDate: 14 August 2010', '13 Jan 2010'),
#  ('ROLECREATEDDATE: 1978-03-07', '2011-01-19'),
#  ('role_created_date: 15-05-2001', '12-10-2003'),
#  ('Date_Of_Joining: 2009/05/05', '2012/01/23'),
#  ('date_of_transaction: 12/02/1978', '03/11/1995'),
#  ('DATE OF JOINING: April 30th, 2022', 'April 25th, 2022'),
#  ('ENDDATE: April 10th', 'January 25th'),
#  ('LAST MODIFIED DATE: 22nd April', '28th May'),
#  ('LAST MODIFIED DATE: Feb 22nd', 'Mar 4th'),
#  ('LAST MODIFIED DATE: 11th May', '13th May'),
#  ('Modified_Date: April 04, 2002', 'January 18, 2002'),
#  ('END-DATE: 24 September 2021', '29 April 2021'),
#  ('last modified date: Jun 12, 2022', 'August 29, 2022'),
#  ('last_modified_date: 25 January 1986', '13 Jul 1986'),
#  ('roleCreatedDate: 1975-04-29', '1984-05-27'),
#  ('Date-Of-Joining: 27-12-1971', '27-06-2005'),
#  ('endDate: 2006/09/22', '2000/10/30'),
#  ('DateOfBirth: 17/09/2007', '11/01/2010'),
#  ('LAST-AUTHENTICATION-DATE: January 22nd, 2022', 'June 9th, 2022'),
#  ('transactiondate: February 20th', 'January 18th'),
#  ('DATE: 8th January', '11th March'),
#  ('DATE: Apr 19th', 'May 11th'),
#  ('DATE: 25th Feb', '22nd May'),
#  ('TRANSACTIONDATE: November 17, 2014', 'January 08, 2014'),
#  ('Modified-Date: 13 April 2007', '24 April 2007'),
#  ('DATE-OF-COMMENCEMENT: Sep 30, 1973', 'January 14, 1973'),
#  ('Modified_Date: 16 June 1996', '02 Oct 1996'),
#  ('End Date: 2014-05-17', '1970-11-26'),
#  ('date_of_transaction: 21-10-2002', '22-08-2006'),
#  ('modified_date: 1972/07/28', '1999/11/12'),
#  ('LOGIN-CREATED-DATE: 03/06/1992', '17/09/2014'),
#  ('PUBLISHED_DATE: January 7th, 2022', 'April 21st, 2022'),
#  ('LAST_MODIFIED_DATE: May 26th', 'May 14th'),
#  ('DATEOFJOINING: 18th March', '10th May'),
#  ('DATEOFJOINING: Jan 5th', 'Apr 3rd'),
#  ('DATEOFJOINING: 29th Mar', '23rd Feb'),
#  ('Date Of Transaction: February 20, 1973', 'December 19, 1973'),
#  ('date of birth: 24 July 1994', '11 December 1994'),
#  ('End Date: Sep 12, 1971', 'December 28, 1971'),
#  ('TRANSACTION-DATE: 28 June 2014', '27 Mar 2014'),
#  ('Modified-Date: 2022-05-14', '1993-04-25'),
#  ('end_date: 20-09-2002', '11-03-2002'),
#  ('Transaction Date: 1985/03/06', '1973/11/01'),
#  ('Last-Authentication-Date: 10/05/1998', '09/03/2011'),
#  ('Transaction_Date: May 4th, 2022', 'January 25th, 2022'),
#  ('transaction-date: January 20th', 'May 18th'),
#  ('publisheddate: 18th June', '3rd June'),
#  ('publisheddate: Feb 27th', 'Apr 16th'),
#  ('publisheddate: 1st Mar', '14th Mar'),
#  ('published_date: January 14, 2011', 'October 09, 2011'),
#  ('login created date: 15 December 2022', '11 October 2022'),
#  ('DATE OF BIRTH: Apr 09, 2013', 'December 21, 2013'),
#  ('dateofcommencement: 14 August 1973', '16 Nov 1973'),
#  ('TRANSACTION DATE: 1977-03-02', '1985-08-18'),
#  ('date of purchase: 05-07-2002', '21-10-2010'),
#  ('DATEOFBIRTH: 1971/11/18', '2005/09/03'),
#  ('Creation Date: 08/06/2019', '20/05/2012'),
#  ('lastModifiedDate: March 19th, 2022', 'February 26th, 2022'),
#  ('dateofjoining: June 9th', 'April 21st'),
#  ('Date_Of_Purchase: 16th April', '3rd January'),
#  ('Date_Of_Purchase: Jan 21st', 'May 20th'),
#  ('Date_Of_Purchase: 19th Jun', '18th Feb'),
#  ('publisheddate: January 23, 1997', 'March 24, 1997'),
#  ('ROLE-CREATED-DATE: 11 April 1978', '24 November 1978'),
#  ('Date Of Transaction: Aug 08, 1996', 'May 24, 1996'),
#  ('DATE OF JOINING: 17 January 1998', '25 Jul 1998'),
#  ('End_Date: 1993-06-08', '1976-03-21'),
#  ('transaction date: 10-08-1983', '12-10-1982'),
#  ('LOGIN-CREATED-DATE: 1972/04/06', '1988/06/22'),
#  ('Date-Of-Birth: 24/06/2005', '07/04/1971'),
#  ('DATE_OF_PURCHASE: March 19th, 2022', 'April 11th, 2022'),
#  ('END_DATE: April 27th', 'February 14th'),
#  ('LAST-AUTHENTICATION-DATE: 30th May', '12th March'),
#  ('LAST-AUTHENTICATION-DATE: May 22nd', 'Jun 12th'),
#  ('LAST-AUTHENTICATION-DATE: 9th Jun', '30th May'),
#  ('Creation_Date: September 16, 1986', 'July 22, 1986'),
#  ('Transaction Date: 07 August 2012', '06 August 2012'),
#  ('TransactionDate: Nov 25, 1988', 'May 18, 1988'),
#  ('MODIFIED DATE: 21 November 2007', '06 Jun 2007'),
#  ('creation date: 1994-11-16', '1977-01-15'),
#  ('publishedDate: 26-01-1992', '11-04-2001'),
#  ('dateOfJoining: 2005/06/26', '2001/10/26'),
#  ('Login-Created-Date: 13/02/1978', '28/07/1979'),
#  ('login-created-date: March 14th, 2022', 'February 25th, 2022'),
#  ('CREATION_DATE: February 19th', 'June 2nd'),
#  ('date_of_commencement: 5th February', '26th May'),
#  ('date_of_commencement: Apr 2nd', 'Feb 24th'),
#  ('date_of_commencement: 26th Feb', '9th Apr'),
#  ('DATE_OF_JOINING: January 20, 2021', 'January 16, 2021'),
#  ('ROLECREATEDDATE: 20 March 1985', '14 December 1985'),
#  ('LAST AUTHENTICATION DATE: Nov 22, 2002', 'March 11, 2002'),
#  ('DateOfTransaction: 16 August 2003', '23 Jun 2003'),
#  ('END DATE: 1987-03-13', '1981-03-20'),
#  ('ModifiedDate: 12-02-2009', '04-06-1974'),
#  ('DATE-OF-COMMENCEMENT: 1996/11/02', '1982/09/16'),
#  ('dateOfTransaction: 30/09/2017', '19/08/2008'),
#  ('creation_date: May 26th, 2022', 'January 12th, 2022'),
#  ('creationDate: May 13th', 'January 19th'),
#  ('End-Date: 31st March', '7th January'),
#  ('End-Date: May 16th', 'Feb 18th'),
#  ('End-Date: 15th Jun', '30th May'),
#  ('LOGIN-CREATED-DATE: November 16, 1974', 'January 11, 1974'),
#  ('DATEOFBIRTH: 03 February 1975', '14 March 1975'),
#  ('Modified_Date: Aug 25, 1977', 'October 21, 1977'),
#  ('LOGIN CREATED DATE: 22 April 2011', '23 May 2011'),
#  ('DATE-OF-TRANSACTION: 2001-10-31', '1971-08-30'),
#  ('TRANSACTION-DATE: 07-01-1974', '13-08-2017'),
#  ('lastmodifieddate: 1971/06/08', '2011/10/17'),
#  ('TRANSACTION_DATE: 26/10/1970', '08/03/2009'),
#  ('modified-date: April 1st, 2022', 'April 3rd, 2022'),
#  ('TRANSACTION_DATE: June 12th', 'April 13th'),
#  ('DATE-OF-TRANSACTION: 16th June', '5th March'),
#  ('DATE-OF-TRANSACTION: May 30th', 'Apr 21st'),
#  ('DATE-OF-TRANSACTION: 1st Apr', '13th Jan'),
#  ('date_of_commencement: April 17, 2002', 'September 19, 2002'),
#  ('DATE OF COMMENCEMENT: 20 January 1980', '02 September 1980'),
#  ('login_created_date: Jan 20, 1972', 'January 18, 1972'),
#  ('loginCreatedDate: 05 August 1990', '20 Nov 1990'),
#  ('TRANSACTIONDATE: 2000-04-06', '1983-12-13'),
#  ('lastmodifieddate: 02-01-1986', '07-01-2018'),
#  ('date-of-purchase: 1985/05/01', '2002/10/05'),
#  ('loginCreatedDate: 29/02/2000', '11/09/1971'),
#  ('LastModifiedDate: February 13th, 2022', 'January 12th, 2022'),
#  ('DATE OF COMMENCEMENT: May 1st', 'May 12th'),
#  ('DATE OF TRANSACTION: 16th May', '18th January'),
#  ('DATE OF TRANSACTION: Apr 30th', 'Apr 28th'),
#  ('DATE OF TRANSACTION: 27th May', '9th May'),
#  ('DATE: June 18, 1986', 'July 14, 1986'),
#  ('PublishedDate: 14 March 2010', '24 March 2010'),
#  ('DATEOFTRANSACTION: Dec 21, 2016', 'April 25, 2016'),
#  ('transaction-date: 16 October 1984', '14 Apr 1984'),
#  ('Date-Of-Purchase: 2000-12-28', '1988-03-29'),
#  ('LAST_AUTHENTICATION_DATE: 26-09-1977', '04-08-2014'),
#  ('DATEOFBIRTH: 2009/02/28', '1974/11/22'),
#  ('dateofjoining: 21/10/1992', '08/08/1987'),
#  ('Date Of Birth: January 9th, 2022', 'June 17th, 2022'),
#  ('lastAuthenticationDate: June 14th', 'January 31st'),
#  ('transaction-date: 29th March', '14th February'),
#  ('transaction-date: May 3rd', 'Jun 18th'),
#  ('transaction-date: 3rd May', '6th Jun'),
#  ('dateofcommencement: November 09, 1995', 'January 30, 1995'),
#  ('dateOfCommencement: 18 August 2005', '21 May 2005'),
#  ('Date: Jun 27, 1973', 'May 04, 1973'),
#  ('CREATION-DATE: 13 March 1979', '06 Aug 1979'),
#  ('DATE_OF_JOINING: 1990-11-09', '2009-01-15'),
#  ('PUBLISHED-DATE: 25-12-2011', '11-09-1992'),
#  ('DATEOFCOMMENCEMENT: 1983/08/10', '2021/04/27'),
#  ('Date-Of-Joining: 21/08/1983', '08/03/2012'),
#  ('End-Date: June 17th, 2022', 'March 31st, 2022'),
#  ('TransactionDate: June 14th', 'March 25th'),
#  ('ROLE-CREATED-DATE: 12th February', '3rd January'),
#  ('ROLE-CREATED-DATE: Mar 2nd', 'Jan 29th'),
#  ('ROLE-CREATED-DATE: 2nd Jun', '16th May'),
#  ('Date_Of_Joining: December 13, 1986', 'May 13, 1986'),
#  ('creation_date: 24 September 1990', '15 May 1990'),
#  ('Creation-Date: Apr 11, 1970', 'July 26, 1970'),
#  ('Last_Modified_Date: 25 September 2012', '14 Apr 2012'),
#  ('PUBLISHED_DATE: 2004-02-19', '1977-03-17'),
#  ('Creation Date: 30-03-1980', '03-12-2010'),
#  ('TransactionDate: 2017/06/13', '1990/11/20'),
#  ('Published-Date: 12/09/2004', '07/05/1995'),
#  ('LAST_AUTHENTICATION_DATE: June 13th, 2022', 'May 30th, 2022'),
#  ('date-of-commencement: April 23rd', 'March 2nd'),
#  ('DATE OF COMMENCEMENT: 16th June', '26th April'),
#  ('DATE OF COMMENCEMENT: Mar 27th', 'Jun 9th'),
#  ('DATE OF COMMENCEMENT: 8th Apr', '15th Feb'),
#  ('END DATE: September 16, 1976', 'September 17, 1976'),
#  ('DateOfTransaction: 18 October 2014', '06 November 2014'),
#  ('TransactionDate: Jul 01, 1981', 'February 22, 1981'),
#  ('date_of_purchase: 28 February 2002', '18 Jan 2002'),
#  ('login_created_date: 2003-03-23', '1990-03-07'),
#  ('date of joining: 03-06-2011', '09-05-2006'),
#  ('transaction date: 1977/01/09', '2020/07/24'),
#  ('creation-date: 28/09/1980', '20/02/1999'),
#  ('DATE_OF_BIRTH: March 20th, 2022', 'May 22nd, 2022'),
#  ('Modified-Date: March 4th', 'January 7th'),
#  ('Date-Of-Transaction: 1st May', '28th March'),
#  ('Date-Of-Transaction: May 10th', 'May 20th'),
#  ('Date-Of-Transaction: 1st Mar', '18th Jan'),
#  ('loginCreatedDate: April 14, 1979', 'August 21, 1979'),
#  ('date-of-birth: 08 August 1987', '17 May 1987'),
#  ('role-created-date: Aug 29, 1972', 'March 31, 1972'),
#  ('MODIFIED DATE: 12 November 1975', '31 Aug 1975'),
#  ('dateOfJoining: 2004-12-15', '2010-06-28'),
#  ('dateofcommencement: 17-01-2002', '30-05-1984'),
#  ('published date: 1980/02/24', '1994/11/27'),
#  ('date of purchase: 01/01/1984', '18/11/2016'),
#  ('date_of_purchase: January 17th, 2022', 'January 6th, 2022'),
#  ('Modified-Date: January 20th', 'June 2nd'),
#  ('Transaction-Date: 4th June', '24th January'),
#  ('Transaction-Date: Jan 5th', 'Apr 17th'),
#  ...]

# %%
import pandas as pd
res = pd.DataFrame(columns=['input_entity', 'output_entity'])

# %%
res['input_entity'] = input
res['output_entity'] = output

# %%
res.to_csv('date_data.csv', index=False)

# %%
len(res)
# Out:
# 3900
